# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from bs4.element import Comment
import re
import time
from langdetect import detect
import pickle
import numpy as np

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
import nltk
# Out:
# /home/ubuntu/miniconda3/envs/url_mapper/lib/python3.6/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    if element.strip() == "":
        return False
    return True

# %%
def fetch_landing_page(url):
    try:
        response = requests.get(url, timeout=(13,17))
        if response:
            html_page = response.text
            soup = BeautifulSoup(html_page, 'html.parser')
            page_texts = soup.findAll(text=True)
            important_texts = filter(tag_visible, page_texts)
            final_site_content = u".".join(x.strip() for x in important_texts)
            title = soup.title
            if title is not None:
                final_site_content = title.text + " " + final_site_content
            return final_site_content
        else:
            print("Invalid Response")
            return None
    except:
        print("Invalid URL/ Timeout")
        return None

# %% [markdown]
# ## Extracting only useful features and removing null values

# %%
data_full = pd.read_csv('Company-Categorization-DFE.csv', encoding = "ISO-8859-1")

# %%
data_full.head()
# Out:
#     _unit_id  _golden _canary _unit_state  _trusted_judgments  \
# 0  474823173    False     NaN   finalized                   3
# 1  474823174    False     NaN   finalized                   3
# 2  474823175    False     NaN   finalized                   3
# 3  474823176    False     NaN   finalized                   3
# 4  474823177    False     NaN   finalized                   3
#
#   _last_judgment_at   business_category  business_category:confidence  \
# 0       6/5/14 0:29  Financial Services                        1.0000
# 1      6/4/14 22:35  Financial Services                        0.3510
# 2       6/4/14 9:46               Other                        1.0000
# 3      6/3/14 15:03              Retail                        0.6852
# 4      6/4/14 10:32               Other                        0.6738
#
#   description_available  description_available:confidence  \
# 0                   yes                               1.0
# 1                   yes                               1.0
# 2                   yes                               1.0
# 3                   yes                               1.0
# 4                   yes                               1.0
#
#            ...          google1_correct_website  \
# 0          ...             http://central1.com/
# 1          ...            http://ad-agents.com/
# 2          ...              http://ad-tech.com/
# 3          ...               http://addrev.com/
# 4          ...              http://adotmob.com/
#
#    google1_correct_website_found  google1_correct_website_found_gold  \
# 0                            yes                                 NaN
# 1                            yes                                 NaN
# 2                            yes                                 NaN
# 3                            yes                                 NaN
# 4                            yes                                 NaN
#
#    google1_correct_website_foundconfidence google1_correct_website_gold  \
# 0                                     1.00                          NaN
# 1                                     0.64                          NaN
# 2                                     1.00                          NaN
# 3                                     1.00                          NaN
# 4                                     1.00                          NaN
#
#    google1_correct_website_worker_input  \
# 0                     /www.central1.com
# 1                        ad-agents.com/
# 2                           ad-tech.com
# 3                           addrev.com/
# 4                           adotmob.com
#
#    google1_correct_website_worker_inputconfidence  \
# 0                                          0.6538
# 1                                          0.2304
# 2                                          1.0000
# 3                                          0.6538
# 4                                          0.6538
#
#   google1_correct_websiteconfidence                            website  \
# 0                            0.6538                                NaN
# 1                            0.3600  http://www.ad-agents.com/kontakt/
# 2                            1.0000                                NaN
# 3                            1.0000                                NaN
# 4                            1.0000                http://adotmob.com/
#
#   website_match_yn_gold
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 32 columns]

# %%
data = data_full[["business_name", "google1_correct_website", "business_category"]]

# %%
data.shape
# Out:
# (7335, 3)

# %%
data.isna().sum()
# Out:
# business_name               0
# google1_correct_website     0
# business_category          23
# dtype: int64

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (7312, 3)

# %%
data.to_csv("cleaned_data.csv", index=False)

# %%
data = pd.read_csv("cleaned_data.csv")

# %%
data.head(15)
# Out:
#                        business_name               google1_correct_website  \
# 0                          Central 1                  http://central1.com/
# 1   ad agents GmbH Hamburg - Germany                 http://ad-agents.com/
# 2                   ad tech | iMedia                   http://ad-tech.com/
# 3                             AddRev                    http://addrev.com/
# 4                            Adotmob                   http://adotmob.com/
# 5                    BBC Advertising  http://advertising.bbcworldwide.com/
# 6              adyard GmbH - Germany                     http://adyard.de/
# 7                               airG                      http://airg.com/
# 8            All Star Products Group                 http://allstarmg.com/
# 9                          AlmondNet                 http://almondnet.com/
# 10                      antwerpes ag                  http://antwerpes.de/
# 11                    Apartments.com                http://apartments.com/
# 12                   Archer&gt;malmo               http://archermalmo.com/
# 13            As Seen On TV Products                http://asseenontv.com/
# 14                   Assurant Health            http://assuranthealth.com/
#
#      business_category
# 0   Financial Services
# 1   Financial Services
# 2                Other
# 3               Retail
# 4                Other
# 5                Other
# 6                Other
# 7                Other
# 8                  CPG
# 9                Other
# 10               Other
# 11               Other
# 12               Other
# 13              Retail
# 14  Financial Services

# %% [markdown]
# ## Domain count distribution

# %%
data.apply(lambda x: x.google1_correct_website.split('.')[-1], axis=1).value_counts()
# Out:
# com/                                                     4458
# de/                                                       676
# uk/                                                       258
# org/                                                      221
# es/                                                       124
# fr/                                                       111
# it/                                                        99
# net/                                                       88
# edu/                                                       81
# ch/                                                        65
# br/                                                        57
# html                                                       48
# at/                                                        45
# ie/                                                        42
# aspx                                                       40
# pl/                                                        34
# com/en/                                                    32
# au/                                                        31
# ca/                                                        28
# com/de/                                                    24
# eu/                                                        21
# us/                                                        18
# com/uk/                                                    17
# ro/                                                        14
# com/it/                                                    13
# mx/                                                        12
# gov/                                                       10
# de/en/                                                     10
# com/home/                                                   9
# com/es/                                                     9
#                                                          ...
# com/jobs/intro?amp;hashed=0                                 1
# app1t4                                                      1
# com/au-en/                                                  1
# br/pt-br/                                                   1
# de/DE/DE/                                                   1
# com/ie/                                                     1
# de/business/                                                1
# com/hxskafqm-van/ad2one-netherlands/                        1
# com/de-at/                                                  1
# com/ce/                                                     1
# com/?m=Login                                                1
# aspx?FP=C&FR=1&S=1                                          1
# br/#section=noticiat                                        1
# com/adwords/api/docs/test-accounts/                         1
# com/us/en/lr/                                               1
# com/de/home/                                                1
# uk/radio/                                                   1
# de/Home/                                                    1
# com/es-ES/                                                  1
# th/                                                         1
# com/inet/ent_logon/Logon?redirectjsp=true                   1
# com/?lang=en                                                1
# com/Page/mn/en_US/homepage/                                 1
# net/news/skyscanner-kicks-scottish-recruitment-drive/       1
# br/oi/oi-pra-voce/                                          1
# com/welcome/                                                1
# com/au/en/                                                  1
# de/privatkunden/?&start=1401303944                          1
# coop/                                                       1
# com/immc/                                                   1
# Length: 463, dtype: int64

# %% [markdown]
# ## Training only on English sites

# %%
english_domains_filter = data.apply(lambda x: True
                                   if (x.google1_correct_website.split('.')[-1]=='com/' or
                                   x.google1_correct_website.split('.')[-1]=='uk/' or
                                   x.google1_correct_website.split('.')[-1]=='au/' or
                                   x.google1_correct_website.split('.')[-1]=='gov/' or
                                   x.google1_correct_website.split('.')[-1]=='net/' or
                                   x.google1_correct_website.split('.')[-1]=='edu/' or
                                   x.google1_correct_website.split('.')[-1]=='html' or
                                   x.google1_correct_website.split('.')[-1]=='com/en') and
                                   (x.business_name.lower().find('gmbh') == -1)
                                   else False, axis=1)

# %%
data_english = data[english_domains_filter]

# %%
data_english.to_csv('data_english_sites.csv', index=False)

# %%
data_english = pd.read_csv('data_english_sites.csv')

# %%
data_english.head()
# Out:
#       business_name               google1_correct_website   business_category  \
# 0         Central 1                  http://central1.com/  Financial Services
# 1  ad tech | iMedia                   http://ad-tech.com/               Other
# 2            AddRev                    http://addrev.com/              Retail
# 3           Adotmob                   http://adotmob.com/               Other
# 4   BBC Advertising  http://advertising.bbcworldwide.com/               Other
#
#                                         site_content
# 0  Search for:.Join our team, we’re growing..VIEW...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
data_english["business_category"].value_counts()
# Out:
# Other                 2562
# Retail                1011
# Financial Services     432
# CPG                    335
# Travel                 331
# Auto                   162
# Name: business_category, dtype: int64

# %%
data_english['site_content'] = None

# %%
data_english.head()
# Out:
#       business_name               google1_correct_website   business_category  \
# 0         Central 1                  http://central1.com/  Financial Services
# 1  ad tech | iMedia                   http://ad-tech.com/               Other
# 2            AddRev                    http://addrev.com/              Retail
# 3           Adotmob                   http://adotmob.com/               Other
# 4   BBC Advertising  http://advertising.bbcworldwide.com/               Other
#
#   site_content
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %%
tic = time.time()
for i in range(300, 1200):
    if (i%50==0):
        toc = time.time()
        print("Time taken for 50 rows:", toc - tic)
        data_english.to_csv('english_sites_with_content.csv', index=False)
        tic = time.time()
    print("row: ", i)
    url = data_english.iloc[i]["google1_correct_website"]
    data_english.iloc[i]["site_content"] = fetch_landing_page(url)
# Out:
# Time taken for 50 rows: 0.0008819103240966797
# row:  300
# row:  301
# row:  302
# row:  303
# row:  304
# row:  305
# Invalid URL/ Timeout
# row:  306
# row:  307
# row:  308
# row:  309
# row:  310
# Invalid URL/ Timeout
# row:  311
# row:  312
# row:  313
# Invalid Response
# row:  314
# row:  315
# Invalid Response
# row:  316
# Invalid Response
# row:  317
# row:  318
# Invalid Response
# row:  319
# row:  320
# row:  321
# row:  322
# row:  323
# Invalid Response
# row:  324
# row:  325
# row:  326
# row:  327
# row:  328
# row:  329
# row:  330
# row:  331
# row:  332
# row:  333
# row:  334
# row:  335
# row:  336
# row:  337
# row:  338
# Invalid Response
# row:  339
# row:  340
# row:  341
# row:  342
# row:  343
# row:  344
# row:  345
# row:  346
# Invalid Response
# row:  347
# row:  348
# row:  349
# Invalid URL/ Timeout
# Time taken for 50 rows: 436.75583148002625
# row:  350
# Invalid URL/ Timeout
# row:  351
# row:  352
# row:  353
# row:  354
# row:  355
# row:  356
# row:  357
# row:  358
# Invalid URL/ Timeout
# row:  359
# row:  360
# Invalid URL/ Timeout
# row:  361
# row:  362
# row:  363
# row:  364
# row:  365
# row:  366
# Invalid URL/ Timeout
# row:  367
# row:  368
# row:  369
# row:  370
# row:  371
# row:  372
# Invalid Response
# row:  373
# row:  374
# row:  375
# row:  376
# row:  377
# row:  378
# row:  379
# Invalid Response
# row:  380
# row:  381
# row:  382
# row:  383
# row:  384
# row:  385
# Invalid Response
# row:  386
# row:  387
# row:  388
# row:  389
# row:  390
# row:  391
# Invalid URL/ Timeout
# row:  392
# row:  393
# row:  394
# row:  395
# row:  396
# row:  397
# Invalid URL/ Timeout
# row:  398
# row:  399
# Invalid URL/ Timeout
# Time taken for 50 rows: 227.48545861244202
# row:  400
# Invalid Response
# row:  401
# row:  402
# row:  403
# Invalid URL/ Timeout
# row:  404
# row:  405
# row:  406
# row:  407
# row:  408
# row:  409
# row:  410
# row:  411
# Invalid URL/ Timeout
# row:  412
# row:  413
# row:  414
# row:  415
# row:  416
# row:  417
# row:  418
# row:  419
# row:  420
# row:  421
# row:  422
# row:  423
# Invalid URL/ Timeout
# row:  424
# row:  425
# Invalid Response
# row:  426
# Invalid Response
# row:  427
# row:  428
# row:  429
# row:  430
# row:  431
# row:  432
# Invalid Response
# row:  433
# Invalid URL/ Timeout
# row:  434
# row:  435
# row:  436
# row:  437
# Invalid Response
# row:  438
# row:  439
# row:  440
# row:  441
# Invalid Response
# row:  442
# Invalid URL/ Timeout
# row:  443
# Invalid URL/ Timeout
# row:  444
# row:  445
# Invalid Response
# row:  446
# row:  447
# row:  448
# row:  449
# Time taken for 50 rows: 162.2793266773224
# row:  450
# Invalid URL/ Timeout
# row:  451
# row:  452
# row:  453
# row:  454
# row:  455
# row:  456
# row:  457
# row:  458
# row:  459
# row:  460
# row:  461
# row:  462
# row:  463
# row:  464
# row:  465
# row:  466
# Invalid URL/ Timeout
# row:  467
# row:  468
# row:  469
# row:  470
# row:  471
# row:  472
# row:  473
# row:  474
# row:  475
# row:  476
# row:  477
# row:  478
# row:  479
# Invalid URL/ Timeout
# row:  480
# row:  481
# row:  482
# Invalid Response
# row:  483
# row:  484
# row:  485
# row:  486
# row:  487
# row:  488
# row:  489
# row:  490
# row:  491
# row:  492
# row:  493
# row:  494
# Invalid Response
# row:  495
# row:  496
# Invalid URL/ Timeout
# row:  497
# row:  498
# row:  499
# Time taken for 50 rows: 180.3601996898651
# row:  500
# row:  501
# row:  502
# Invalid URL/ Timeout
# row:  503
# row:  504
# Invalid Response
# row:  505
# row:  506
# row:  507
# Invalid URL/ Timeout
# row:  508
# row:  509
# row:  510
# row:  511
# row:  512
# row:  513
# row:  514
# row:  515
# Invalid URL/ Timeout
# row:  516
# Invalid URL/ Timeout
# row:  517
# row:  518
# Invalid URL/ Timeout
# row:  519
# row:  520
# row:  521
# row:  522
# Invalid URL/ Timeout
# row:  523
# Invalid URL/ Timeout
# row:  524
# Invalid URL/ Timeout
# row:  525
# row:  526
# row:  527
# Invalid URL/ Timeout
# row:  528
# row:  529
# row:  530
# row:  531
# row:  532
# row:  533
# row:  534
# row:  535
# row:  536
# row:  537
# row:  538
# row:  539
# Invalid URL/ Timeout
# row:  540
# row:  541
# Invalid URL/ Timeout
# row:  542
# Invalid URL/ Timeout
# row:  543
# row:  544
# Invalid URL/ Timeout
# row:  545
# row:  546
# row:  547
# row:  548
# row:  549
# Time taken for 50 rows: 201.8837697505951
# row:  550
# row:  551
# row:  552
# row:  553
# row:  554
# row:  555
# Invalid Response
# row:  556
# Invalid URL/ Timeout
# row:  557
# row:  558
# Invalid URL/ Timeout
# row:  559
# row:  560
# row:  561
# row:  562
# row:  563
# Invalid URL/ Timeout
# row:  564
# Invalid Response
# row:  565
# row:  566
# row:  567
# row:  568
# row:  569
# row:  570
# row:  571
# Invalid URL/ Timeout
# row:  572
# row:  573
# Invalid URL/ Timeout
# row:  574
# Invalid Response
# row:  575
# Invalid URL/ Timeout
# row:  576
# row:  577
# row:  578
# Invalid URL/ Timeout
# row:  579
# row:  580
# Invalid Response
# row:  581
# row:  582
# Invalid Response
# row:  583
# Invalid Response
# row:  584
# Invalid URL/ Timeout
# row:  585
# Invalid URL/ Timeout
# row:  586
# Invalid Response
# row:  587
# Invalid Response
# row:  588
# row:  589
# row:  590
# Invalid URL/ Timeout
# row:  591
# row:  592
# row:  593
# row:  594
# row:  595
# Invalid URL/ Timeout
# row:  596
# row:  597
# Invalid Response
# row:  598
# Invalid Response
# row:  599
# Time taken for 50 rows: 218.0011579990387
# row:  600
# row:  601
# row:  602
# row:  603
# row:  604
# row:  605
# Invalid URL/ Timeout
# row:  606
# row:  607
# row:  608
# row:  609
# Invalid URL/ Timeout
# row:  610
# Invalid URL/ Timeout
# row:  611
# row:  612
# row:  613
# row:  614
# Invalid URL/ Timeout
# row:  615
# row:  616
# row:  617
# row:  618
# row:  619
# row:  620
# row:  621
# row:  622
# row:  623
# Invalid Response
# row:  624
# Invalid URL/ Timeout
# row:  625
# row:  626
# row:  627
# row:  628
# row:  629
# row:  630
# row:  631
# row:  632
# row:  633
# row:  634
# Invalid Response
# row:  635
# row:  636
# row:  637
# row:  638
# row:  639
# row:  640
# row:  641
# row:  642
# row:  643
# row:  644
# row:  645
# row:  646
# Invalid URL/ Timeout
# row:  647
# row:  648
# row:  649
# Time taken for 50 rows: 195.17321300506592
# row:  650
# row:  651
# row:  652
# Invalid Response
# row:  653
# row:  654
# row:  655
# row:  656
# Invalid URL/ Timeout
# row:  657
# row:  658
# row:  659
# row:  660
# row:  661
# Invalid URL/ Timeout
# row:  662
# row:  663
# row:  664
# row:  665
# row:  666
# row:  667
# row:  668
# row:  669
# row:  670
# row:  671
# Invalid Response
# row:  672
# row:  673
# row:  674
# row:  675
# row:  676
# row:  677
# Invalid URL/ Timeout
# row:  678
# row:  679
# row:  680
# row:  681
# row:  682
# row:  683
# Invalid URL/ Timeout
# row:  684
# row:  685
# row:  686
# Invalid Response
# row:  687
# row:  688
# row:  689
# row:  690
# row:  691
# row:  692
# row:  693
# row:  694
# row:  695
# row:  696
# row:  697
# row:  698
# row:  699
# Time taken for 50 rows: 171.80990505218506
# row:  700
# row:  701
# row:  702
# row:  703
# row:  704
# Invalid Response
# row:  705
# row:  706
# row:  707
# row:  708
# row:  709
# row:  710
# Invalid URL/ Timeout
# row:  711
# row:  712
# row:  713
# row:  714
# row:  715
# row:  716
# row:  717
# row:  718
# row:  719
# Invalid URL/ Timeout
# row:  720
# row:  721
# row:  722
# row:  723
# row:  724
# row:  725
# row:  726
# row:  727
# row:  728
# row:  729
# row:  730
# row:  731
# row:  732
# row:  733
# row:  734
# row:  735
# row:  736
# row:  737
# Invalid URL/ Timeout
# row:  738
# row:  739
# row:  740
# row:  741
# row:  742
# row:  743
# row:  744
# row:  745
# row:  746
# row:  747
# row:  748
# row:  749
# Time taken for 50 rows: 182.7861385345459
# row:  750
# Invalid URL/ Timeout
# row:  751
# row:  752
# row:  753
# row:  754
# row:  755
# row:  756
# row:  757
# row:  758
# row:  759
# row:  760
# row:  761
# row:  762
# row:  763
# row:  764
# row:  765
# Invalid URL/ Timeout
# row:  766
# row:  767
# row:  768
# row:  769
# row:  770
# row:  771
# Invalid Response
# row:  772
# row:  773
# Invalid URL/ Timeout
# row:  774
# row:  775
# row:  776
# row:  777
# row:  778
# Invalid URL/ Timeout
# row:  779
# row:  780
# Invalid URL/ Timeout
# row:  781
# row:  782
# row:  783
# row:  784
# row:  785
# Invalid Response
# row:  786
# row:  787
# row:  788
# row:  789
# row:  790
# row:  791
# row:  792
# Invalid Response
# row:  793
# row:  794
# row:  795
# row:  796
# row:  797
# row:  798
# row:  799
# Time taken for 50 rows: 189.98037338256836
# row:  800
# row:  801
# row:  802
# row:  803
# row:  804
# row:  805
# row:  806
# row:  807
# row:  808
# row:  809
# Invalid URL/ Timeout
# row:  810
# row:  811
# row:  812
# row:  813
# Invalid Response
# row:  814
# row:  815
# row:  816
# row:  817
# row:  818
# row:  819
# row:  820
# row:  821
# row:  822
# Invalid Response
# row:  823
# Invalid Response
# row:  824
# Invalid Response
# row:  825
# row:  826
# row:  827
# row:  828
# row:  829
# row:  830
# row:  831
# row:  832
# row:  833
# row:  834
# row:  835
# Invalid URL/ Timeout
# row:  836
# Invalid URL/ Timeout
# row:  837
# row:  838
# Invalid URL/ Timeout
# row:  839
# row:  840
# row:  841
# row:  842
# row:  843
# row:  844
# Invalid URL/ Timeout
# row:  845
# row:  846
# row:  847
# row:  848
# row:  849
# Time taken for 50 rows: 205.35367250442505
# row:  850
# row:  851
# row:  852
# row:  853
# row:  854
# Invalid Response
# row:  855
# row:  856
# Invalid URL/ Timeout
# row:  857
# row:  858
# Invalid URL/ Timeout
# row:  859
# row:  860
# row:  861
# row:  862
# row:  863
# row:  864
# row:  865
# Invalid URL/ Timeout
# row:  866
# Invalid URL/ Timeout
# row:  867
# Invalid Response
# row:  868
# row:  869
# row:  870
# row:  871
# row:  872
# row:  873
# row:  874
# row:  875
# row:  876
# row:  877
# row:  878
# row:  879
# row:  880
# row:  881
# row:  882
# row:  883
# row:  884
# row:  885
# row:  886
# row:  887
# row:  888
# row:  889
# row:  890
# row:  891
# Invalid Response
# row:  892
# row:  893
# row:  894
# row:  895
# row:  896
# Invalid URL/ Timeout
# row:  897
# row:  898
# Invalid Response
# row:  899
# Time taken for 50 rows: 191.27922201156616
# row:  900
# Invalid URL/ Timeout
# row:  901
# Invalid Response
# row:  902
# row:  903
# row:  904
# row:  905
# row:  906
# row:  907
# row:  908
# row:  909
# row:  910
# row:  911
# row:  912
# row:  913
# row:  914
# row:  915
# row:  916
# row:  917
# row:  918
# Invalid URL/ Timeout
# row:  919
# row:  920
# Invalid URL/ Timeout
# row:  921
# row:  922
# row:  923
# row:  924
# row:  925
# row:  926
# row:  927
# row:  928
# Invalid URL/ Timeout
# row:  929
# Invalid URL/ Timeout
# row:  930
# row:  931
# row:  932
# Invalid URL/ Timeout
# row:  933
# row:  934
# row:  935
# row:  936
# row:  937
# row:  938
# Invalid Response
# row:  939
# row:  940
# row:  941
# row:  942
# Invalid URL/ Timeout
# row:  943
# row:  944
# row:  945
# Invalid Response
# row:  946
# row:  947
# row:  948
# row:  949
# Invalid Response
# Time taken for 50 rows: 231.23782992362976
# row:  950
# row:  951
# Invalid Response
# row:  952
# row:  953
# row:  954
# row:  955
# row:  956
# row:  957
# row:  958
# Invalid URL/ Timeout
# row:  959
# row:  960
# row:  961
# row:  962
# row:  963
# row:  964
# Invalid URL/ Timeout
# row:  965
# Invalid Response
# row:  966
# row:  967
# Invalid URL/ Timeout
# row:  968
# row:  969
# row:  970
# row:  971
# row:  972
# row:  973
# Invalid Response
# row:  974
# row:  975
# Invalid Response
# row:  976
# row:  977
# row:  978
# row:  979
# row:  980
# row:  981
# row:  982
# Invalid URL/ Timeout
# row:  983
# row:  984
# row:  985
# row:  986
# row:  987
# row:  988
# row:  989
# row:  990
# row:  991
# Invalid URL/ Timeout
# row:  992
# row:  993
# row:  994
# row:  995
# row:  996
# row:  997
# row:  998
# row:  999
# Time taken for 50 rows: 203.84243297576904
# row:  1000
# row:  1001
# row:  1002
# row:  1003
# row:  1004
# row:  1005
# Invalid Response
# row:  1006
# row:  1007
# row:  1008
# row:  1009
# row:  1010
# row:  1011
# row:  1012
# row:  1013
# row:  1014
# Invalid URL/ Timeout
# row:  1015
# row:  1016
# Invalid URL/ Timeout
# row:  1017
# row:  1018
# row:  1019
# row:  1020
# row:  1021
# row:  1022
# row:  1023
# Invalid Response
# row:  1024
# row:  1025
# row:  1026
# row:  1027
# row:  1028
# row:  1029
# row:  1030
# Invalid URL/ Timeout
# row:  1031
# row:  1032
# row:  1033
# row:  1034
# row:  1035
# Invalid Response
# row:  1036
# row:  1037
# row:  1038
# row:  1039
# row:  1040
# row:  1041
# Invalid Response
# row:  1042
# row:  1043
# row:  1044
# row:  1045
# Invalid URL/ Timeout
# row:  1046
# row:  1047
# row:  1048
# row:  1049
# Time taken for 50 rows: 165.75963878631592
# row:  1050
# row:  1051
# row:  1052
# row:  1053
# row:  1054
# row:  1055
# row:  1056
# row:  1057
# row:  1058
# Invalid Response
# row:  1059
# Invalid URL/ Timeout
# row:  1060
# Invalid URL/ Timeout
# row:  1061
# row:  1062
# Invalid URL/ Timeout
# row:  1063
# Invalid URL/ Timeout
# row:  1064
# row:  1065
# row:  1066
# row:  1067
# row:  1068
# row:  1069
# row:  1070
# row:  1071
# row:  1072
# Invalid URL/ Timeout
# row:  1073
# row:  1074
# Invalid URL/ Timeout
# row:  1075
# Invalid Response
# row:  1076
# row:  1077
# row:  1078
# row:  1079
# Invalid URL/ Timeout
# row:  1080
# row:  1081
# row:  1082
# row:  1083
# Invalid Response
# row:  1084
# row:  1085
# row:  1086
# row:  1087
# row:  1088
# row:  1089
# row:  1090
# row:  1091
# row:  1092
# row:  1093
# Invalid URL/ Timeout
# row:  1094
# row:  1095
# row:  1096
# row:  1097
# row:  1098
# row:  1099
# Time taken for 50 rows: 233.10482454299927
# row:  1100
# row:  1101
# Invalid URL/ Timeout
# row:  1102
# row:  1103
# row:  1104
# row:  1105
# row:  1106
# Invalid Response
# row:  1107
# row:  1108
# row:  1109
# row:  1110
# row:  1111
# row:  1112
# row:  1113
# row:  1114
# Invalid URL/ Timeout
# row:  1115
# row:  1116
# row:  1117
# row:  1118
# row:  1119
# row:  1120
# row:  1121
# Invalid URL/ Timeout
# row:  1122
# row:  1123
# Invalid URL/ Timeout
# row:  1124
# row:  1125
# row:  1126
# row:  1127
# row:  1128
# row:  1129
# row:  1130
# row:  1131
# Invalid URL/ Timeout
# row:  1132
# row:  1133
# row:  1134
# Invalid Response
# row:  1135
# row:  1136
# row:  1137
# row:  1138
# row:  1139
# row:  1140
# row:  1141
# Invalid URL/ Timeout
# row:  1142
# row:  1143
# row:  1144
# row:  1145
# row:  1146
# Invalid URL/ Timeout
# row:  1147
# row:  1148
# row:  1149
# Time taken for 50 rows: 211.11134505271912
# row:  1150
# row:  1151
# Invalid URL/ Timeout
# row:  1152
# Invalid URL/ Timeout
# row:  1153
# Invalid Response
# row:  1154
# row:  1155
# row:  1156
# row:  1157
# row:  1158
# row:  1159
# row:  1160
# row:  1161
# row:  1162
# row:  1163
# row:  1164
# row:  1165
# Invalid Response
# row:  1166
# row:  1167
# row:  1168
# row:  1169
# row:  1170
# Invalid URL/ Timeout
# row:  1171
# row:  1172
# row:  1173
# row:  1174
# row:  1175
# Invalid Response
# row:  1176
# Invalid Response
# row:  1177
# row:  1178
# Invalid URL/ Timeout
# row:  1179
# row:  1180
# row:  1181
# row:  1182
# row:  1183
# row:  1184
# row:  1185
# row:  1186
# row:  1187
# row:  1188
# row:  1189
# row:  1190
# row:  1191
# row:  1192
# row:  1193
# row:  1194
# row:  1195
# row:  1196
# row:  1197
# Invalid Response
# row:  1198
# row:  1199

# %%
data_english = data_english[["business_name", "google1_correct_website", "business_category", "site_content"
]]
# Out:
#       business_name               google1_correct_website   business_category  \
# 0         Central 1                  http://central1.com/  Financial Services
# 1  ad tech | iMedia                   http://ad-tech.com/               Other
# 2            AddRev                    http://addrev.com/              Retail
# 3           Adotmob                   http://adotmob.com/               Other
# 4   BBC Advertising  http://advertising.bbcworldwide.com/               Other
#
#                                         site_content
# 0  Search for:.Join our team, we’re growing..VIEW...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
data_english.to_csv('english_sites_with_content.csv', index=False)

# %%
subdata = data_english[:1199].dropna()

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_vector = tfidf.fit_transform(subdata["site_content"])

# %%
X_tfidf = tfidf_vector.toarray()

# %%
X_tfidf.shape
# Out:
# (959, 43539)

# %%
le = LabelEncoder()
y_tfidf = le.fit_transform(subdata['business_category'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_tfidf, test_size=0.3, random_state=42)

# %%
lr = LogisticRegression(random_state=42)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(X_test, y_test)
# Out:
# 0.5625

# %% [markdown]
# ## Change of Approach: Labelling Languages and training separate classifiers

# %%
url = data.iloc[1]["google1_correct_website"]

# %%
text = fetch_landing_page(url)

# %%
from langdetect import detect

# %%
detect(text)
# Out:
# 'de'

# %%
data['site-content'] = None
data['site-language'] = None
data.head()
# Out:
#                       business_name google1_correct_website  \
# 0                         Central 1    http://central1.com/
# 1  ad agents GmbH Hamburg - Germany   http://ad-agents.com/
# 2                  ad tech | iMedia     http://ad-tech.com/
# 3                            AddRev      http://addrev.com/
# 4                           Adotmob     http://adotmob.com/
#
#     business_category site-content site-language
# 0  Financial Services         None          None
# 1  Financial Services         None          None
# 2               Other         None          None
# 3              Retail         None          None
# 4               Other         None          None

# %%
data.to_csv('data_with_lang_labels.csv')

# %%
tic = time.time()
for i in range(4500, data.shape[0]):
    if (i%100==0):
        toc = time.time()
        print("Time taken for 100 rows:", toc - tic)
        data.to_csv('data_with_lang_labels.csv', index=False)
        tic = time.time()
    print("row: ", i)
    url = data.iloc[i]["google1_correct_website"]
    content = fetch_landing_page(url)
    if (content is not None) and (content != ''):
        data.at[i, "site-content"] = content
        try:
            lang = detect(content)    
            data.at[i,"site-language"] = lang
        except:
            continue
# Out:
# Time taken for 100 rows: 0.00043892860412597656
# row:  4500
# row:  4501
# row:  4502
# row:  4503
# row:  4504
# row:  4505
# row:  4506
# row:  4507
# Invalid URL/ Timeout
# row:  4508
# row:  4509
# row:  4510
# Invalid URL/ Timeout
# row:  4511
# row:  4512
# row:  4513
# row:  4514
# row:  4515
# row:  4516
# row:  4517
# row:  4518
# Invalid URL/ Timeout
# row:  4519
# row:  4520
# ERROR:urllib3.connection:Certificate did not match expected hostname: wavecloud.com. Certificate: {'subject': ((('jurisdictionCountryName', 'US'),), (('jurisdictionStateOrProvinceName', 'Arizona'),), (('businessCategory', 'Private Organization'),), (('serialNumber', 'R17247303'),), (('countryName', 'US'),), (('stateOrProvinceName', 'Arizona'),), (('localityName', 'Scottsdale'),), (('organizationName', 'Special Domain Services, LLC'),), (('commonName', 'shortener.secureserver.net'),)), 'issuer': ((('countryName', 'US'),), (('stateOrProvinceName', 'Arizona'),), (('localityName', 'Scottsdale'),), (('organizationName', 'Starfield Technologies, Inc.'),), (('organizationalUnitName', 'http://certs.starfieldtech.com/repository/'),), (('commonName', 'Starfield Secure Certificate Authority - G2'),)), 'version': 3, 'serialNumber': 'EF5927289A9FDADB', 'notBefore': 'Sep 26 22:40:51 2018 GMT', 'notAfter': 'Sep 26 22:40:51 2020 GMT', 'subjectAltName': (('DNS', 'shortener.secureserver.net'), ('DNS', 'www.shortener.secureserver.net')), 'OCSP': ('http://ocsp.starfieldtech.com/',), 'caIssuers': ('http://certificates.starfieldtech.com/repository/sfig2.crt',), 'crlDistributionPoints': ('http://crl.starfieldtech.com/sfig2s3-1.crl',)}
# Invalid URL/ Timeout
# row:  4521
# Invalid URL/ Timeout
# row:  4522
# row:  4523
# row:  4524
# row:  4525
# row:  4526
# row:  4527
# row:  4528
# row:  4529
# row:  4530
# Invalid URL/ Timeout
# row:  4531
# row:  4532
# row:  4533
# row:  4534
# Invalid Response
# row:  4535
# Invalid URL/ Timeout
# row:  4536
# row:  4537
# row:  4538
# row:  4539
# row:  4540
# row:  4541
# row:  4542
# row:  4543
# row:  4544
# row:  4545
# Invalid URL/ Timeout
# row:  4546
# row:  4547
# row:  4548
# Invalid Response
# row:  4549
# row:  4550
# row:  4551
# row:  4552
# row:  4553
# Invalid Response
# row:  4554
# row:  4555
# row:  4556
# row:  4557
# row:  4558
# row:  4559
# row:  4560
# row:  4561
# Invalid Response
# row:  4562
# row:  4563
# row:  4564
# Invalid URL/ Timeout
# row:  4565
# Invalid Response
# row:  4566
# Invalid URL/ Timeout
# row:  4567
# row:  4568
# Invalid URL/ Timeout
# row:  4569
# Invalid Response
# row:  4570
# row:  4571
# Invalid Response
# row:  4572
# row:  4573
# Invalid URL/ Timeout
# row:  4574
# row:  4575
# row:  4576
# row:  4577
# row:  4578
# row:  4579
# row:  4580
# WARNING:urllib3.connectionpool:Failed to parse headers (url=http://marquisjet.com:80/): [MissingHeaderBodySeparatorDefect()], unparsed data: '/\r\nServer: BigIP\r\nConnection: Keep-Alive\r\nContent-Length: 0\r\n\r\n'
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda/envs/cv/lib/python3.6/site-packages/urllib3/connectionpool.py", line 396, in _make_request
#     assert_header_parsing(httplib_response.msg)
#   File "/home/ubuntu/miniconda/envs/cv/lib/python3.6/site-packages/urllib3/util/response.py", line 66, in assert_header_parsing
#     raise HeaderParsingError(defects=defects, unparsed_data=unparsed_data)
# urllib3.exceptions.HeaderParsingError: [MissingHeaderBodySeparatorDefect()], unparsed data: '/\r\nServer: BigIP\r\nConnection: Keep-Alive\r\nContent-Length: 0\r\n\r\n'
# Invalid URL/ Timeout
# row:  4581
# row:  4582
# row:  4583
# Invalid URL/ Timeout
# row:  4584
# row:  4585
# row:  4586
# Invalid Response
# row:  4587
# row:  4588
# row:  4589
# Invalid Response
# row:  4590
# Invalid Response
# row:  4591
# Invalid Response
# row:  4592
# row:  4593
# row:  4594
# Invalid Response
# row:  4595
# Invalid URL/ Timeout
# row:  4596
# row:  4597
# Invalid URL/ Timeout
# row:  4598
# row:  4599
# Time taken for 100 rows: 432.5011909008026
# row:  4600
# row:  4601
# Invalid URL/ Timeout
# row:  4602
# row:  4603
# row:  4604
# row:  4605
# row:  4606
# row:  4607
# row:  4608
# row:  4609
# row:  4610
# row:  4611
# row:  4612
# row:  4613
# row:  4614
# row:  4615
# row:  4616
# row:  4617
# row:  4618
# row:  4619
# row:  4620
# row:  4621
# row:  4622
# Invalid URL/ Timeout
# row:  4623
# row:  4624
# row:  4625
# row:  4626
# Invalid URL/ Timeout
# row:  4627
# Invalid Response
# row:  4628
# row:  4629
# row:  4630
# row:  4631
# row:  4632
# row:  4633
# row:  4634
# row:  4635
# row:  4636
# row:  4637
# Invalid Response
# row:  4638
# Invalid URL/ Timeout
# row:  4639
# row:  4640
# row:  4641
# row:  4642
# row:  4643
# Invalid URL/ Timeout
# row:  4644
# row:  4645
# row:  4646
# row:  4647
# row:  4648
# row:  4649
# Invalid Response
# row:  4650
# row:  4651
# row:  4652
# Invalid URL/ Timeout
# row:  4653
# row:  4654
# row:  4655
# Invalid URL/ Timeout
# row:  4656
# row:  4657
# Invalid Response
# row:  4658
# Invalid URL/ Timeout
# row:  4659
# row:  4660
# Invalid URL/ Timeout
# row:  4661
# Invalid Response
# row:  4662
# row:  4663
# row:  4664
# row:  4665
# Invalid URL/ Timeout
# row:  4666
# row:  4667
# Invalid URL/ Timeout
# row:  4668
# row:  4669
# row:  4670
# row:  4671
# Invalid Response
# row:  4672
# row:  4673
# Invalid Response
# row:  4674
# row:  4675
# row:  4676
# Invalid Response
# row:  4677
# row:  4678
# Invalid URL/ Timeout
# row:  4679
# row:  4680
# Invalid URL/ Timeout
# row:  4681
# row:  4682
# row:  4683
# row:  4684
# row:  4685
# Invalid URL/ Timeout
# row:  4686
# row:  4687
# row:  4688
# row:  4689
# row:  4690
# row:  4691
# Invalid Response
# row:  4692
# Invalid URL/ Timeout
# row:  4693
# Invalid Response
# row:  4694
# row:  4695
# row:  4696
# Invalid URL/ Timeout
# row:  4697
# row:  4698
# row:  4699
# Invalid Response
# Time taken for 100 rows: 377.7956528663635
# row:  4700
# row:  4701
# Invalid Response
# row:  4702
# row:  4703
# row:  4704
# row:  4705
# row:  4706
# row:  4707
# row:  4708
# row:  4709
# row:  4710
# row:  4711
# row:  4712
# row:  4713
# Invalid Response
# row:  4714
# row:  4715
# row:  4716
# Invalid URL/ Timeout
# row:  4717
# row:  4718
# row:  4719
# row:  4720
# row:  4721
# row:  4722
# row:  4723
# Invalid URL/ Timeout
# row:  4724
# row:  4725
# row:  4726
# row:  4727
# row:  4728
# row:  4729
# row:  4730
# row:  4731
# row:  4732
# row:  4733
# row:  4734
# row:  4735
# row:  4736
# row:  4737
# row:  4738
# Invalid URL/ Timeout
# row:  4739
# row:  4740
# row:  4741
# Invalid URL/ Timeout
# row:  4742
# Invalid URL/ Timeout
# row:  4743
# row:  4744
# row:  4745
# row:  4746
# row:  4747
# row:  4748
# Invalid Response
# row:  4749
# row:  4750
# row:  4751
# row:  4752
# row:  4753
# row:  4754
# row:  4755
# Invalid URL/ Timeout
# row:  4756
# row:  4757
# row:  4758
# row:  4759
# Invalid URL/ Timeout
# row:  4760
# Invalid Response
# row:  4761
# row:  4762
# row:  4763
# row:  4764
# row:  4765
# row:  4766
# row:  4767
# row:  4768
# row:  4769
# row:  4770
# row:  4771
# row:  4772
# row:  4773
# Invalid Response
# row:  4774
# row:  4775
# row:  4776
# row:  4777
# row:  4778
# row:  4779
# row:  4780
# row:  4781
# row:  4782
# row:  4783
# row:  4784
# row:  4785
# row:  4786
# row:  4787
# row:  4788
# row:  4789
# Invalid Response
# row:  4790
# row:  4791
# row:  4792
# Invalid Response
# row:  4793
# row:  4794
# Invalid Response
# row:  4795
# row:  4796
# row:  4797
# row:  4798
# row:  4799
# Invalid URL/ Timeout
# Time taken for 100 rows: 370.7543594837189
# row:  4800
# row:  4801
# row:  4802
# row:  4803
# row:  4804
# row:  4805
# row:  4806
# row:  4807
# row:  4808
# row:  4809
# row:  4810
# row:  4811
# row:  4812
# row:  4813
# row:  4814
# row:  4815
# row:  4816
# row:  4817
# Invalid URL/ Timeout
# row:  4818
# row:  4819
# row:  4820
# row:  4821
# Invalid Response
# row:  4822
# row:  4823
# ERROR:urllib3.connection:Certificate did not match expected hostname: alconemarketing.com. Certificate: {'subject': ((('countryName', 'US'),), (('postalCode', '75063'),), (('stateOrProvinceName', 'Texas'),), (('localityName', 'Irving'),), (('streetAddress', '7850 N. Belt Line Rd'),), (('organizationName', 'Consolidated Data Services'),), (('organizationalUnitName', 'Consolidated Data Services'),), (('organizationalUnitName', 'Enterprise SSL Wildcard'),), (('commonName', '*.alcone.com'),)), 'issuer': ((('countryName', 'US'),), (('stateOrProvinceName', 'DE'),), (('localityName', 'Wilmington'),), (('organizationName', 'Corporation Service Company'),), (('commonName', 'Trusted Secure Certificate Authority 5'),)), 'version': 3, 'serialNumber': '2B51A34D3361A2FCF169793BC1499A05', 'notBefore': 'Nov 21 00:00:00 2018 GMT', 'notAfter': 'Nov 20 23:59:59 2020 GMT', 'subjectAltName': (('DNS', '*.alcone.com'), ('DNS', 'alcone.com')), 'OCSP': ('http://ocsp.usertrust.com',), 'caIssuers': ('http://crt.usertrust.com/TrustedSecureCertificateAuthority5.crt',), 'crlDistributionPoints': ('http://crl.usertrust.com/TrustedSecureCertificateAuthority5.crl',)}
# Invalid URL/ Timeout
# row:  4824
# row:  4825
# ERROR:urllib3.connection:Certificate did not match expected hostname: alenty.com. Certificate: {'subject': ((('countryName', 'US'),), (('stateOrProvinceName', 'New York'),), (('localityName', 'New York'),), (('organizationName', 'AppNexus, Inc.'),), (('commonName', 'appnexus.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'DigiCert Inc'),), (('organizationalUnitName', 'www.digicert.com'),), (('commonName', 'GeoTrust TLS RSA CA G1'),)), 'version': 3, 'serialNumber': '05A83E78D75842AA755AFA5920BD8CC5', 'notBefore': 'Sep  5 00:00:00 2018 GMT', 'notAfter': 'Oct  5 12:00:00 2019 GMT', 'subjectAltName': (('DNS', 'appnexus.com'), ('DNS', 'www.appnexus.com'), ('DNS', 'www.appnexus.net'), ('DNS', 'appnexus.net')), 'OCSP': ('http://status.geotrust.com',), 'caIssuers': ('http://cacerts.geotrust.com/GeoTrustTLSRSACAG1.crt',), 'crlDistributionPoints': ('http://cdp.geotrust.com/GeoTrustTLSRSACAG1.crl',)}
# Invalid URL/ Timeout
# row:  4826
# Invalid URL/ Timeout
# row:  4827
# Invalid URL/ Timeout
# row:  4828
# row:  4829
# Invalid Response
# row:  4830
# row:  4831
# row:  4832
# row:  4833
# row:  4834
# ERROR:urllib3.connection:Certificate did not match expected hostname: allianzdeutschland.de. Certificate: {'subject': ((('countryName', 'DE'),), (('stateOrProvinceName', 'Bayern'),), (('localityName', 'Muenchen'),), (('organizationName', 'Allianz Technology SE'),), (('organizationalUnitName', 'Deutschland AG'),), (('commonName', 'www.allianzdeutschland.de'),)), 'issuer': ((('countryName', 'BM'),), (('organizationName', 'QuoVadis Limited'),), (('commonName', 'QuoVadis Global SSL ICA G3'),)), 'version': 3, 'serialNumber': '0D8009FC96416A2664F259315B9706DD7B2E6150', 'notBefore': 'Aug 14 06:01:37 2018 GMT', 'notAfter': 'Aug 14 06:10:00 2020 GMT', 'subjectAltName': (('DNS', 'www.allianzdeutschland.de'),), 'OCSP': ('http://ocsp.quovadisglobal.com',), 'caIssuers': ('http://trust.quovadisglobal.com/qvsslg3.crt',), 'crlDistributionPoints': ('http://crl.quovadisglobal.com/qvsslg3.crl',)}
# Invalid URL/ Timeout
# row:  4835
# row:  4836
# row:  4837
# row:  4838
# row:  4839
# Invalid URL/ Timeout
# row:  4840
# row:  4841
# row:  4842
# row:  4843
# row:  4844
# row:  4845
# Invalid Response
# row:  4846
# Invalid Response
# row:  4847
# Invalid Response
# row:  4848
# row:  4849
# row:  4850
# Invalid URL/ Timeout
# row:  4851
# row:  4852
# row:  4853
# row:  4854
# row:  4855
# Invalid URL/ Timeout
# row:  4856
# row:  4857
# row:  4858
# row:  4859
# row:  4860
# Invalid URL/ Timeout
# row:  4861
# Invalid URL/ Timeout
# row:  4862
# row:  4863
# row:  4864
# row:  4865
# row:  4866
# row:  4867
# row:  4868
# row:  4869
# row:  4870
# row:  4871
# row:  4872
# row:  4873
# row:  4874
# row:  4875
# row:  4876
# row:  4877
# row:  4878
# row:  4879
# row:  4880
# row:  4881
# row:  4882
# row:  4883
# row:  4884
# Invalid Response
# row:  4885
# row:  4886
# row:  4887
# row:  4888
# row:  4889
# row:  4890
# row:  4891
# Invalid URL/ Timeout
# row:  4892
# Invalid URL/ Timeout
# row:  4893
# row:  4894
# row:  4895
# row:  4896
# row:  4897
# row:  4898
# row:  4899
# Time taken for 100 rows: 427.1248652935028
# row:  4900
# row:  4901
# row:  4902
# row:  4903
# row:  4904
# Invalid Response
# row:  4905
# row:  4906
# row:  4907
# row:  4908
# Invalid Response
# row:  4909
# Invalid URL/ Timeout
# row:  4910
# row:  4911
# row:  4912
# row:  4913
# Invalid Response
# row:  4914
# row:  4915
# Invalid Response
# row:  4916
# row:  4917
# row:  4918
# row:  4919
# row:  4920
# Invalid URL/ Timeout
# row:  4921
# row:  4922
# row:  4923
# row:  4924
# row:  4925
# row:  4926
# row:  4927
# row:  4928
# row:  4929
# row:  4930
# row:  4931
# row:  4932
# row:  4933
# Invalid Response
# row:  4934
# row:  4935
# row:  4936
# Invalid Response
# row:  4937
# row:  4938
# row:  4939
# row:  4940
# row:  4941
# row:  4942
# row:  4943
# row:  4944
# row:  4945
# row:  4946
# row:  4947
# row:  4948
# row:  4949
# row:  4950
# Invalid URL/ Timeout
# row:  4951
# row:  4952
# row:  4953
# row:  4954
# row:  4955
# row:  4956
# row:  4957
# row:  4958
# row:  4959
# Invalid URL/ Timeout
# row:  4960
# row:  4961
# Invalid URL/ Timeout
# row:  4962
# row:  4963
# row:  4964
# Invalid URL/ Timeout
# row:  4965
# row:  4966
# row:  4967
# row:  4968
# row:  4969
# row:  4970
# row:  4971
# Invalid URL/ Timeout
# row:  4972
# Invalid Response
# row:  4973
# row:  4974
# row:  4975
# Invalid URL/ Timeout
# row:  4976
# row:  4977
# row:  4978
# row:  4979
# row:  4980
# Invalid Response
# row:  4981
# Invalid URL/ Timeout
# row:  4982
# row:  4983
# row:  4984
# row:  4985
# row:  4986
# Invalid Response
# row:  4987
# row:  4988
# row:  4989
# row:  4990
# row:  4991
# row:  4992
# Invalid Response
# row:  4993
# row:  4994
# row:  4995
# row:  4996
# row:  4997
# row:  4998
# row:  4999
# Time taken for 100 rows: 416.76864218711853
# row:  5000
# row:  5001
# row:  5002
# row:  5003
# row:  5004
# row:  5005
# Invalid Response
# row:  5006
# row:  5007
# row:  5008
# row:  5009
# row:  5010
# row:  5011
# Invalid URL/ Timeout
# row:  5012
# Invalid URL/ Timeout
# row:  5013
# row:  5014
# Invalid URL/ Timeout
# row:  5015
# row:  5016
# ERROR:urllib3.connection:Certificate did not match expected hostname: bluekettle.ca. Certificate: {'subject': ((('commonName', 'www.bluekettle.ca'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', "Let's Encrypt Authority X3"),)), 'version': 3, 'serialNumber': '04B4940A74015EDDCF0811A733EDF2AAEE27', 'notBefore': 'May  9 13:57:43 2019 GMT', 'notAfter': 'Aug  7 13:57:43 2019 GMT', 'subjectAltName': (('DNS', 'www.bluekettle.ca'),), 'OCSP': ('http://ocsp.int-x3.letsencrypt.org',), 'caIssuers': ('http://cert.int-x3.letsencrypt.org/',)}
# Invalid URL/ Timeout
# row:  5017
# row:  5018
# row:  5019
# row:  5020
# row:  5021
# row:  5022
# Invalid Response
# row:  5023
# row:  5024
# row:  5025
# row:  5026
# row:  5027
# row:  5028
# row:  5029
# Invalid Response
# row:  5030
# row:  5031
# row:  5032
# row:  5033
# row:  5034
# row:  5035
# row:  5036
# row:  5037
# row:  5038
# row:  5039
# row:  5040
# row:  5041
# row:  5042
# Invalid Response
# row:  5043
# row:  5044
# row:  5045
# row:  5046
# row:  5047
# Invalid URL/ Timeout
# row:  5048
# row:  5049
# row:  5050
# row:  5051
# row:  5052
# Invalid URL/ Timeout
# row:  5053
# row:  5054
# row:  5055
# Invalid Response
# row:  5056
# row:  5057
# row:  5058
# Invalid Response
# row:  5059
# row:  5060
# row:  5061
# row:  5062
# Invalid Response
# row:  5063
# Invalid Response
# row:  5064
# row:  5065
# row:  5066
# row:  5067
# Invalid URL/ Timeout
# row:  5068
# row:  5069
# row:  5070
# row:  5071
# row:  5072
# row:  5073
# row:  5074
# row:  5075
# row:  5076
# row:  5077
# Invalid URL/ Timeout
# row:  5078
# row:  5079
# row:  5080
# row:  5081
# row:  5082
# row:  5083
# row:  5084
# Invalid Response
# row:  5085
# row:  5086
# Invalid Response
# row:  5087
# row:  5088
# row:  5089
# row:  5090
# row:  5091
# row:  5092
# row:  5093
# row:  5094
# row:  5095
# row:  5096
# row:  5097
# row:  5098
# row:  5099
# Time taken for 100 rows: 368.2477641105652
# row:  5100
# row:  5101
# Invalid Response
# row:  5102
# row:  5103
# row:  5104
# row:  5105
# row:  5106
# Invalid URL/ Timeout
# row:  5107
# row:  5108
# row:  5109
# row:  5110
# Invalid URL/ Timeout
# row:  5111
# row:  5112
# row:  5113
# Invalid Response
# row:  5114
# row:  5115
# row:  5116
# row:  5117
# row:  5118
# row:  5119
# row:  5120
# Invalid Response
# row:  5121
# row:  5122
# row:  5123
# row:  5124
# row:  5125
# Invalid Response
# row:  5126
# row:  5127
# row:  5128
# row:  5129
# Invalid URL/ Timeout
# row:  5130
# row:  5131
# row:  5132
# row:  5133
# row:  5134
# row:  5135
# row:  5136
# Invalid Response
# row:  5137
# row:  5138
# row:  5139
# row:  5140
# row:  5141
# Invalid Response
# row:  5142
# row:  5143
# row:  5144
# row:  5145
# row:  5146
# row:  5147
# row:  5148
# row:  5149
# row:  5150
# row:  5151
# row:  5152
# row:  5153
# row:  5154
# row:  5155
# row:  5156
# row:  5157
# row:  5158
# row:  5159
# row:  5160
# Invalid URL/ Timeout
# row:  5161
# row:  5162
# row:  5163
# row:  5164
# row:  5165
# row:  5166
# row:  5167
# row:  5168
# row:  5169
# row:  5170
# Invalid URL/ Timeout
# row:  5171
# Invalid URL/ Timeout
# row:  5172
# row:  5173
# row:  5174
# row:  5175
# row:  5176
# row:  5177
# row:  5178
# row:  5179
# row:  5180
# row:  5181
# Invalid URL/ Timeout
# row:  5182
# row:  5183
# row:  5184
# row:  5185
# row:  5186
# row:  5187
# row:  5188
# row:  5189
# row:  5190
# row:  5191
# row:  5192
# Invalid Response
# row:  5193
# row:  5194
# ERROR:urllib3.connection:Certificate did not match expected hostname: envisionitmedia.com. Certificate: {'subject': ((('commonName', 'destinationenv.com'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', "Let's Encrypt Authority X3"),)), 'version': 3, 'serialNumber': '033DBB90ADDD04BBDD50C89D5EDEDDF40F89', 'notBefore': 'May 23 20:21:49 2019 GMT', 'notAfter': 'Aug 21 20:21:49 2019 GMT', 'subjectAltName': (('DNS', 'destinationenv.com'), ('DNS', 'www.destinationenv.com')), 'OCSP': ('http://ocsp.int-x3.letsencrypt.org',), 'caIssuers': ('http://cert.int-x3.letsencrypt.org/',)}
# Invalid URL/ Timeout
# row:  5195
# row:  5196
# Invalid Response
# row:  5197
# row:  5198
# row:  5199
# Time taken for 100 rows: 437.96310806274414
# row:  5200
# row:  5201
# row:  5202
# row:  5203
# row:  5204
# row:  5205
# row:  5206
# row:  5207
# Invalid Response
# row:  5208
# row:  5209
# Invalid Response
# row:  5210
# row:  5211
# Invalid URL/ Timeout
# row:  5212
# row:  5213
# row:  5214
# row:  5215
# Invalid URL/ Timeout
# row:  5216
# row:  5217
# Invalid Response
# row:  5218
# row:  5219
# row:  5220
# row:  5221
# row:  5222
# row:  5223
# row:  5224
# row:  5225
# Invalid URL/ Timeout
# row:  5226
# row:  5227
# row:  5228
# row:  5229
# row:  5230
# row:  5231
# Invalid Response
# row:  5232
# row:  5233
# row:  5234
# row:  5235
# row:  5236
# row:  5237
# row:  5238
# Invalid Response
# row:  5239
# row:  5240
# Invalid Response
# row:  5241
# Invalid Response
# row:  5242
# row:  5243
# row:  5244
# row:  5245
# row:  5246
# row:  5247
# row:  5248
# row:  5249
# row:  5250
# row:  5251
# row:  5252
# row:  5253
# row:  5254
# row:  5255
# row:  5256
# row:  5257
# row:  5258
# row:  5259
# row:  5260
# row:  5261
# row:  5262
# row:  5263
# row:  5264
# row:  5265
# row:  5266
# row:  5267
# Invalid URL/ Timeout
# row:  5268
# row:  5269
# row:  5270
# row:  5271
# row:  5272
# row:  5273
# row:  5274
# Invalid Response
# row:  5275
# row:  5276
# Invalid Response
# row:  5277
# Invalid Response
# row:  5278
# row:  5279
# row:  5280
# row:  5281
# row:  5282
# Invalid URL/ Timeout
# row:  5283
# row:  5284
# row:  5285
# row:  5286
# row:  5287
# row:  5288
# Invalid URL/ Timeout
# row:  5289
# row:  5290
# row:  5291
# row:  5292
# row:  5293
# row:  5294
# row:  5295
# row:  5296
# Invalid Response
# row:  5297
# row:  5298
# Invalid Response
# row:  5299
# Time taken for 100 rows: 337.20468258857727
# row:  5300
# row:  5301
# row:  5302
# row:  5303
# row:  5304
# row:  5305
# row:  5306
# row:  5307
# Invalid URL/ Timeout
# row:  5308
# ERROR:urllib3.connection:Certificate did not match expected hostname: dpdhl.com. Certificate: {'subject': ((('countryName', 'DE'),), (('stateOrProvinceName', 'Nordrhein-Westfalen'),), (('localityName', 'Bonn'),), (('organizationName', 'Deutsche Post AG'),), (('commonName', 'origin.dpdhl.com'),)), 'issuer': ((('countryName', 'BE'),), (('organizationName', 'GlobalSign nv-sa'),), (('commonName', 'GlobalSign Organization Validation CA - SHA256 - G2'),)), 'version': 3, 'serialNumber': '2B21198463A9F5ABB76F224B', 'notBefore': 'Jan 24 08:51:04 2019 GMT', 'notAfter': 'Jan 25 08:51:04 2020 GMT', 'subjectAltName': (('DNS', 'origin.dpdhl.com'), ('DNS', 'annualreport2015.dpdhl.com'), ('DNS', 'annualreport2016.dpdhl.com'), ('DNS', 'annualreport2017.dpdhl.com'), ('DNS', 'geschaeftsbericht2015.dpdhl.com'), ('DNS', 'geschaeftsbericht2016.dpdhl.com'), ('DNS', 'geschaeftsbericht2017.dpdhl.com'), ('DNS', 'geschaeftsbericht2018.dpdhl.com'), ('DNS', 'origin.test.dpdhl.com')), 'OCSP': ('http://ocsp2.globalsign.com/gsorganizationvalsha2g2',), 'caIssuers': ('http://secure.globalsign.com/cacert/gsorganizationvalsha2g2r1.crt',), 'crlDistributionPoints': ('http://crl.globalsign.com/gs/gsorganizationvalsha2g2.crl',)}
# Invalid URL/ Timeout
# row:  5309
# row:  5310
# row:  5311
# Invalid URL/ Timeout
# row:  5312
# Invalid URL/ Timeout
# row:  5313
# row:  5314
# row:  5315
# Invalid URL/ Timeout
# row:  5316
# row:  5317
# row:  5318
# row:  5319
# Invalid URL/ Timeout
# row:  5320
# Invalid Response
# row:  5321
# row:  5322
# Invalid Response
# row:  5323
# row:  5324
# row:  5325
# row:  5326
# Invalid Response
# row:  5327
# row:  5328
# Invalid URL/ Timeout
# row:  5329
# Invalid URL/ Timeout
# row:  5330
# Invalid URL/ Timeout
# row:  5331
# row:  5332
# row:  5333
# row:  5334
# row:  5335
# row:  5336
# row:  5337
# row:  5338
# Invalid Response
# row:  5339
# row:  5340
# row:  5341
# row:  5342
# row:  5343
# row:  5344
# row:  5345
# row:  5346
# Invalid Response
# row:  5347
# row:  5348
# row:  5349
# row:  5350
# row:  5351
# row:  5352
# row:  5353
# row:  5354
# Invalid URL/ Timeout
# row:  5355
# row:  5356
# Invalid URL/ Timeout
# row:  5357
# row:  5358
# row:  5359
# row:  5360
# row:  5361
# row:  5362
# Invalid Response
# row:  5363
# row:  5364
# Invalid URL/ Timeout
# row:  5365
# row:  5366
# Invalid URL/ Timeout
# row:  5367
# row:  5368
# row:  5369
# Invalid URL/ Timeout
# row:  5370
# Invalid Response
# row:  5371
# row:  5372
# row:  5373
# row:  5374
# Invalid URL/ Timeout
# row:  5375
# row:  5376
# row:  5377
# Invalid Response
# row:  5378
# row:  5379
# row:  5380
# row:  5381
# row:  5382
# row:  5383
# row:  5384
# row:  5385
# Invalid URL/ Timeout
# row:  5386
# row:  5387
# Invalid Response
# row:  5388
# row:  5389
# row:  5390
# Invalid URL/ Timeout
# row:  5391
# Invalid URL/ Timeout
# row:  5392
# Invalid Response
# row:  5393
# row:  5394
# row:  5395
# row:  5396
# row:  5397
# Invalid URL/ Timeout
# row:  5398
# Invalid URL/ Timeout
# row:  5399
# Time taken for 100 rows: 551.0387485027313
# row:  5400
# row:  5401
# row:  5402
# row:  5403
# row:  5404
# row:  5405
# row:  5406
# row:  5407
# row:  5408
# row:  5409
# row:  5410
# row:  5411
# row:  5412
# row:  5413
# row:  5414
# row:  5415
# row:  5416
# row:  5417
# Invalid Response
# row:  5418
# row:  5419
# Invalid Response
# row:  5420
# Invalid URL/ Timeout
# row:  5421
# Invalid URL/ Timeout
# row:  5422
# Invalid Response
# row:  5423
# Invalid URL/ Timeout
# row:  5424
# row:  5425
# row:  5426
# Invalid URL/ Timeout
# row:  5427
# row:  5428
# row:  5429
# row:  5430
# row:  5431
# Invalid Response
# row:  5432
# Invalid Response
# row:  5433
# Invalid URL/ Timeout
# row:  5434
# row:  5435
# Invalid Response
# row:  5436
# row:  5437
# row:  5438
# row:  5439
# row:  5440
# Invalid URL/ Timeout
# row:  5441
# row:  5442
# row:  5443
# Invalid URL/ Timeout
# row:  5444
# row:  5445
# row:  5446
# row:  5447
# row:  5448
# Invalid Response
# row:  5449
# row:  5450
# row:  5451
# row:  5452
# Invalid Response
# row:  5453
# Invalid URL/ Timeout
# row:  5454
# row:  5455
# row:  5456
# Invalid Response
# row:  5457
# Invalid Response
# row:  5458
# row:  5459
# Invalid Response
# row:  5460
# row:  5461
# Invalid Response
# row:  5462
# row:  5463
# row:  5464
# row:  5465
# row:  5466
# row:  5467
# row:  5468
# row:  5469
# Invalid Response
# row:  5470
# row:  5471
# row:  5472
# Invalid Response
# row:  5473
# row:  5474
# row:  5475
# row:  5476
# row:  5477
# row:  5478
# row:  5479
# Invalid URL/ Timeout
# row:  5480
# row:  5481
# row:  5482
# row:  5483
# row:  5484
# row:  5485
# row:  5486
# row:  5487
# row:  5488
# row:  5489
# row:  5490
# row:  5491
# Invalid URL/ Timeout
# row:  5492
# row:  5493
# row:  5494
# row:  5495
# row:  5496
# row:  5497
# row:  5498
# row:  5499
# Time taken for 100 rows: 440.06264758110046
# row:  5500
# row:  5501
# row:  5502
# Invalid Response
# row:  5503
# row:  5504
# row:  5505
# row:  5506
# row:  5507
# row:  5508
# row:  5509
# row:  5510
# row:  5511
# row:  5512
# Invalid URL/ Timeout
# row:  5513
# row:  5514
# row:  5515
# row:  5516
# Invalid URL/ Timeout
# row:  5517
# Invalid URL/ Timeout
# row:  5518
# row:  5519
# Invalid URL/ Timeout
# row:  5520
# Invalid URL/ Timeout
# row:  5521
# Invalid Response
# row:  5522
# Invalid Response
# row:  5523
# row:  5524
# row:  5525
# row:  5526
# row:  5527
# row:  5528
# row:  5529
# row:  5530
# row:  5531
# row:  5532
# Invalid URL/ Timeout
# row:  5533
# row:  5534
# row:  5535
# row:  5536
# row:  5537
# row:  5538
# Invalid Response
# row:  5539
# row:  5540
# row:  5541
# row:  5542
# row:  5543
# row:  5544
# row:  5545
# row:  5546
# row:  5547
# row:  5548
# Invalid URL/ Timeout
# row:  5549
# row:  5550
# Invalid URL/ Timeout
# row:  5551
# row:  5552
# Invalid Response
# row:  5553
# row:  5554
# row:  5555
# row:  5556
# row:  5557
# row:  5558
# row:  5559
# Invalid URL/ Timeout
# row:  5560
# row:  5561
# row:  5562
# row:  5563
# row:  5564
# Invalid URL/ Timeout
# row:  5565
# row:  5566
# row:  5567
# row:  5568
# row:  5569
# row:  5570
# Invalid URL/ Timeout
# row:  5571
# row:  5572
# Invalid Response
# row:  5573
# row:  5574
# Invalid URL/ Timeout
# row:  5575
# row:  5576
# Invalid Response
# row:  5577
# Invalid Response
# row:  5578
# row:  5579
# row:  5580
# row:  5581
# Invalid URL/ Timeout
# row:  5582
# row:  5583
# row:  5584
# row:  5585
# row:  5586
# Invalid Response
# row:  5587
# Invalid URL/ Timeout
# row:  5588
# Invalid URL/ Timeout
# row:  5589
# row:  5590
# row:  5591
# row:  5592
# row:  5593
# row:  5594
# Invalid URL/ Timeout
# row:  5595
# Invalid URL/ Timeout
# row:  5596
# row:  5597
# row:  5598
# Invalid URL/ Timeout
# row:  5599
# Time taken for 100 rows: 6999.535050153732
# row:  5600
# row:  5601
# row:  5602
# Invalid Response
# row:  5603
# row:  5604
# row:  5605
# row:  5606
# row:  5607
# Invalid Response
# row:  5608
# row:  5609
# row:  5610
# row:  5611
# row:  5612
# row:  5613
# row:  5614
# row:  5615
# Invalid Response
# row:  5616
# row:  5617
# row:  5618
# Invalid URL/ Timeout
# row:  5619
# row:  5620
# Invalid Response
# row:  5621
# row:  5622
# row:  5623
# Invalid URL/ Timeout
# row:  5624
# Invalid URL/ Timeout
# row:  5625
# row:  5626
# row:  5627
# Invalid Response
# row:  5628
# Invalid Response
# row:  5629
# row:  5630
# row:  5631
# row:  5632
# row:  5633
# row:  5634
# row:  5635
# row:  5636
# row:  5637
# Invalid Response
# row:  5638
# row:  5639
# row:  5640
# row:  5641
# Invalid URL/ Timeout
# row:  5642
# Invalid Response
# row:  5643
# row:  5644
# row:  5645
# row:  5646
# Invalid URL/ Timeout
# row:  5647
# row:  5648
# Invalid Response
# row:  5649
# Invalid Response
# row:  5650
# Invalid URL/ Timeout
# row:  5651
# row:  5652
# row:  5653
# row:  5654
# row:  5655
# row:  5656
# row:  5657
# row:  5658
# row:  5659
# row:  5660
# row:  5661
# row:  5662
# row:  5663
# row:  5664
# row:  5665
# row:  5666
# row:  5667
# row:  5668
# row:  5669
# row:  5670
# row:  5671
# row:  5672
# Invalid URL/ Timeout
# row:  5673
# row:  5674
# Invalid URL/ Timeout
# row:  5675
# row:  5676
# row:  5677
# Invalid Response
# row:  5678
# row:  5679
# Invalid URL/ Timeout
# row:  5680
# row:  5681
# row:  5682
# row:  5683
# row:  5684
# row:  5685
# Invalid Response
# row:  5686
# row:  5687
# row:  5688
# row:  5689
# row:  5690
# Invalid URL/ Timeout
# row:  5691
# row:  5692
# Invalid Response
# row:  5693
# row:  5694
# row:  5695
# row:  5696
# row:  5697
# row:  5698
# row:  5699
# Time taken for 100 rows: 332.22408056259155
# row:  5700
# Invalid Response
# row:  5701
# row:  5702
# row:  5703
# row:  5704
# row:  5705
# row:  5706
# Invalid Response
# row:  5707
# Invalid Response
# row:  5708
# row:  5709
# row:  5710
# Invalid URL/ Timeout
# row:  5711
# Invalid URL/ Timeout
# row:  5712
# row:  5713
# row:  5714
# Invalid Response
# row:  5715
# Invalid URL/ Timeout
# row:  5716
# row:  5717
# row:  5718
# row:  5719
# Invalid Response
# row:  5720
# Invalid Response
# row:  5721
# row:  5722
# Invalid Response
# row:  5723
# row:  5724
# row:  5725
# row:  5726
# row:  5727
# row:  5728
# row:  5729
# row:  5730
# row:  5731
# row:  5732
# row:  5733
# row:  5734
# row:  5735
# row:  5736
# row:  5737
# row:  5738
# row:  5739
# row:  5740
# row:  5741
# row:  5742
# row:  5743
# row:  5744
# row:  5745
# row:  5746
# Invalid URL/ Timeout
# row:  5747
# row:  5748
# Invalid URL/ Timeout
# row:  5749
# Invalid URL/ Timeout
# row:  5750
# Invalid URL/ Timeout
# row:  5751
# Invalid URL/ Timeout
# row:  5752
# row:  5753
# Invalid Response
# row:  5754
# row:  5755
# row:  5756
# row:  5757
# row:  5758
# row:  5759
# row:  5760
# row:  5761
# row:  5762
# Invalid Response
# row:  5763
# row:  5764
# row:  5765
# row:  5766
# row:  5767
# row:  5768
# row:  5769
# Invalid URL/ Timeout
# row:  5770
# row:  5771
# row:  5772
# row:  5773
# Invalid URL/ Timeout
# row:  5774
# row:  5775
# row:  5776
# Invalid URL/ Timeout
# row:  5777
# row:  5778
# row:  5779
# row:  5780
# row:  5781
# row:  5782
# Invalid URL/ Timeout
# row:  5783
# row:  5784
# row:  5785
# row:  5786
# row:  5787
# row:  5788
# Invalid Response
# row:  5789
# Invalid Response
# row:  5790
# row:  5791
# row:  5792
# Invalid URL/ Timeout
# row:  5793
# Invalid URL/ Timeout
# row:  5794
# row:  5795
# row:  5796
# row:  5797
# row:  5798
# row:  5799
# Time taken for 100 rows: 348.2117028236389
# row:  5800
# row:  5801
# row:  5802
# Invalid URL/ Timeout
# row:  5803
# Invalid URL/ Timeout
# row:  5804
# row:  5805
# row:  5806
# row:  5807
# row:  5808
# row:  5809
# row:  5810
# row:  5811
# Invalid URL/ Timeout
# row:  5812
# row:  5813
# Invalid Response
# row:  5814
# row:  5815
# row:  5816
# row:  5817
# row:  5818
# row:  5819
# row:  5820
# row:  5821
# row:  5822
# row:  5823
# Invalid Response
# row:  5824
# row:  5825
# row:  5826
# row:  5827
# row:  5828
# Invalid URL/ Timeout
# row:  5829
# row:  5830
# row:  5831
# Invalid Response
# row:  5832
# row:  5833
# row:  5834
# row:  5835
# row:  5836
# row:  5837
# Invalid URL/ Timeout
# row:  5838
# row:  5839
# row:  5840
# row:  5841
# row:  5842
# row:  5843
# row:  5844
# row:  5845
# row:  5846
# row:  5847
# row:  5848
# row:  5849
# row:  5850
# Invalid Response
# row:  5851
# row:  5852
# row:  5853
# row:  5854
# row:  5855
# row:  5856
# row:  5857
# Invalid Response
# row:  5858
# row:  5859
# row:  5860
# row:  5861
# row:  5862
# row:  5863
# row:  5864
# row:  5865
# row:  5866
# row:  5867
# row:  5868
# row:  5869
# row:  5870
# row:  5871
# row:  5872
# Invalid URL/ Timeout
# row:  5873
# row:  5874
# row:  5875
# row:  5876
# row:  5877
# row:  5878
# Invalid URL/ Timeout
# row:  5879
# row:  5880
# row:  5881
# row:  5882
# row:  5883
# Invalid Response
# row:  5884
# Invalid Response
# row:  5885
# row:  5886
# row:  5887
# row:  5888
# row:  5889
# row:  5890
# row:  5891
# row:  5892
# row:  5893
# row:  5894
# row:  5895
# Invalid Response
# row:  5896
# Invalid Response
# row:  5897
# row:  5898
# row:  5899
# Time taken for 100 rows: 406.6728837490082
# row:  5900
# Invalid Response
# row:  5901
# row:  5902
# row:  5903
# row:  5904
# row:  5905
# Invalid Response
# row:  5906
# Invalid Response
# row:  5907
# Invalid Response
# row:  5908
# Invalid Response
# row:  5909
# row:  5910
# row:  5911
# row:  5912
# Invalid Response
# row:  5913
# row:  5914
# row:  5915
# row:  5916
# Invalid Response
# row:  5917
# row:  5918
# row:  5919
# row:  5920
# Invalid Response
# row:  5921
# row:  5922
# row:  5923
# Invalid Response
# row:  5924
# row:  5925
# row:  5926
# row:  5927
# row:  5928
# row:  5929
# row:  5930
# row:  5931
# row:  5932
# row:  5933
# row:  5934
# row:  5935
# row:  5936
# Invalid Response
# row:  5937
# row:  5938
# row:  5939
# row:  5940
# row:  5941
# row:  5942
# row:  5943
# Invalid Response
# row:  5944
# Invalid URL/ Timeout
# row:  5945
# row:  5946
# row:  5947
# row:  5948
# row:  5949
# row:  5950
# row:  5951
# row:  5952
# Invalid URL/ Timeout
# row:  5953
# row:  5954
# row:  5955
# row:  5956
# row:  5957
# row:  5958
# Invalid Response
# row:  5959
# row:  5960
# Invalid URL/ Timeout
# row:  5961
# row:  5962
# row:  5963
# row:  5964
# row:  5965
# row:  5966
# row:  5967
# row:  5968
# row:  5969
# row:  5970
# row:  5971
# row:  5972
# row:  5973
# row:  5974
# Invalid Response
# row:  5975
# row:  5976
# row:  5977
# row:  5978
# Invalid Response
# row:  5979
# row:  5980
# row:  5981
# row:  5982
# row:  5983
# row:  5984
# row:  5985
# row:  5986
# Invalid URL/ Timeout
# row:  5987
# row:  5988
# row:  5989
# row:  5990
# row:  5991
# Invalid URL/ Timeout
# row:  5992
# row:  5993
# row:  5994
# Invalid Response
# row:  5995
# row:  5996
# row:  5997
# row:  5998
# row:  5999
# Time taken for 100 rows: 379.13476395606995
# row:  6000
# row:  6001
# row:  6002
# row:  6003
# row:  6004
# Invalid Response
# row:  6005
# ERROR:urllib3.connection:Certificate did not match expected hostname: marinsoftware.co.uk. Certificate: {'subject': ((('countryName', 'US'),), (('stateOrProvinceName', 'California'),), (('localityName', 'San Francisco'),), (('organizationName', 'Marin Software Inc.'),), (('commonName', '*.marinsoftware.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'DigiCert Inc'),), (('commonName', 'DigiCert SHA2 Secure Server CA'),)), 'version': 3, 'serialNumber': '055F677DE2E12350DFF2F1F5D65FC9AA', 'notBefore': 'Jun 18 00:00:00 2018 GMT', 'notAfter': 'Jul 13 12:00:00 2020 GMT', 'subjectAltName': (('DNS', '*.marinsoftware.com'), ('DNS', 'marinsoftware.com'), ('DNS', 'app.marinsoftware.com'), ('DNS', 'www.marinsoftware.com'), ('DNS', 'pro.marinsoftware.com')), 'OCSP': ('http://ocsp.digicert.com',), 'caIssuers': ('http://cacerts.digicert.com/DigiCertSHA2SecureServerCA.crt',), 'crlDistributionPoints': ('http://crl3.digicert.com/ssca-sha2-g6.crl', 'http://crl4.digicert.com/ssca-sha2-g6.crl')}
# Invalid URL/ Timeout
# row:  6006
# row:  6007
# Invalid URL/ Timeout
# row:  6008
# row:  6009
# row:  6010
# row:  6011
# row:  6012
# row:  6013
# row:  6014
# row:  6015
# row:  6016
# row:  6017
# row:  6018
# row:  6019
# row:  6020
# row:  6021
# row:  6022
# Invalid Response
# row:  6023
# row:  6024
# row:  6025
# row:  6026
# row:  6027
# row:  6028
# row:  6029
# row:  6030
# row:  6031
# row:  6032
# row:  6033
# row:  6034
# row:  6035
# row:  6036
# row:  6037
# row:  6038
# row:  6039
# row:  6040
# row:  6041
# row:  6042
# row:  6043
# row:  6044
# row:  6045
# row:  6046
# Invalid URL/ Timeout
# row:  6047
# row:  6048
# Invalid URL/ Timeout
# row:  6049
# row:  6050
# row:  6051
# row:  6052
# row:  6053
# row:  6054
# row:  6055
# row:  6056
# row:  6057
# row:  6058
# row:  6059
# row:  6060
# row:  6061
# Invalid Response
# row:  6062
# row:  6063
# ERROR:urllib3.connection:Certificate did not match expected hostname: monetizeit.com. Certificate: {'subject': ((('countryName', 'DE'),), (('stateOrProvinceName', 'Bayern'),), (('localityName', 'München'),), (('organizationName', 'Team Internet AG'),), (('commonName', '*.parkingcrew.net'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'DigiCert Inc'),), (('organizationalUnitName', 'www.digicert.com'),), (('commonName', 'Thawte TLS RSA CA G1'),)), 'version': 3, 'serialNumber': '017129E41208E5BA4A34454A044BF9B2', 'notBefore': 'Jul 25 00:00:00 2018 GMT', 'notAfter': 'Jul 24 12:00:00 2020 GMT', 'subjectAltName': (('DNS', '*.parkingcrew.net'), ('DNS', 'parkingcrew.net')), 'OCSP': ('http://status.thawte.com',), 'caIssuers': ('http://cacerts.thawte.com/ThawteTLSRSACAG1.crt',), 'crlDistributionPoints': ('http://cdp.thawte.com/ThawteTLSRSACAG1.crl',)}
# Invalid URL/ Timeout
# row:  6064
# row:  6065
# row:  6066
# row:  6067
# row:  6068
# Invalid URL/ Timeout
# row:  6069
# row:  6070
# row:  6071
# row:  6072
# row:  6073
# row:  6074
# row:  6075
# row:  6076
# row:  6077
# Invalid URL/ Timeout
# row:  6078
# row:  6079
# Invalid URL/ Timeout
# row:  6080
# row:  6081
# row:  6082
# row:  6083
# row:  6084
# row:  6085
# Invalid URL/ Timeout
# row:  6086
# row:  6087
# row:  6088
# row:  6089
# row:  6090
# row:  6091
# row:  6092
# row:  6093
# row:  6094
# row:  6095
# row:  6096
# row:  6097
# row:  6098
# row:  6099
# Time taken for 100 rows: 369.3452343940735
# row:  6100
# row:  6101
# row:  6102
# row:  6103
# row:  6104
# row:  6105
# row:  6106
# row:  6107
# row:  6108
# row:  6109
# row:  6110
# row:  6111
# Invalid Response
# row:  6112
# row:  6113
# row:  6114
# row:  6115
# row:  6116
# row:  6117
# row:  6118
# row:  6119
# row:  6120
# row:  6121
# row:  6122
# row:  6123
# row:  6124
# row:  6125
# row:  6126
# Invalid Response
# row:  6127
# row:  6128
# row:  6129
# row:  6130
# Invalid URL/ Timeout
# row:  6131
# row:  6132
# Invalid URL/ Timeout
# row:  6133
# row:  6134
# row:  6135
# row:  6136
# row:  6137
# row:  6138
# row:  6139
# row:  6140
# row:  6141
# row:  6142
# row:  6143
# row:  6144
# Invalid Response
# row:  6145
# row:  6146
# row:  6147
# row:  6148
# row:  6149
# row:  6150
# row:  6151
# row:  6152
# Invalid URL/ Timeout
# row:  6153
# row:  6154
# Invalid URL/ Timeout
# row:  6155
# row:  6156
# row:  6157
# row:  6158
# row:  6159
# row:  6160
# row:  6161
# Invalid URL/ Timeout
# row:  6162
# row:  6163
# row:  6164
# row:  6165
# row:  6166
# Invalid URL/ Timeout
# row:  6167
# row:  6168
# row:  6169
# row:  6170
# row:  6171
# row:  6172
# row:  6173
# Invalid Response
# row:  6174
# row:  6175
# Invalid Response
# row:  6176
# row:  6177
# row:  6178
# row:  6179
# row:  6180
# row:  6181
# row:  6182
# row:  6183
# row:  6184
# row:  6185
# row:  6186
# row:  6187
# row:  6188
# Invalid URL/ Timeout
# row:  6189
# row:  6190
# row:  6191
# Invalid Response
# row:  6192
# row:  6193
# row:  6194
# row:  6195
# row:  6196
# row:  6197
# row:  6198
# Invalid URL/ Timeout
# row:  6199
# Time taken for 100 rows: 387.17822265625
# row:  6200
# row:  6201
# row:  6202
# row:  6203
# row:  6204
# row:  6205
# row:  6206
# row:  6207
# row:  6208
# row:  6209
# Invalid URL/ Timeout
# row:  6210
# Invalid URL/ Timeout
# row:  6211
# row:  6212
# row:  6213
# Invalid Response
# row:  6214
# row:  6215
# Invalid URL/ Timeout
# row:  6216
# row:  6217
# row:  6218
# Invalid URL/ Timeout
# row:  6219
# row:  6220
# row:  6221
# Invalid Response
# row:  6222
# row:  6223
# row:  6224
# row:  6225
# row:  6226
# row:  6227
# Invalid URL/ Timeout
# row:  6228
# row:  6229
# row:  6230
# row:  6231
# row:  6232
# row:  6233
# row:  6234
# row:  6235
# row:  6236
# row:  6237
# row:  6238
# row:  6239
# row:  6240
# row:  6241
# row:  6242
# row:  6243
# row:  6244
# row:  6245
# row:  6246
# row:  6247
# row:  6248
# row:  6249
# row:  6250
# row:  6251
# row:  6252
# row:  6253
# row:  6254
# row:  6255
# row:  6256
# row:  6257
# row:  6258
# Invalid URL/ Timeout
# row:  6259
# row:  6260
# row:  6261
# row:  6262
# row:  6263
# Invalid Response
# row:  6264
# Invalid URL/ Timeout
# row:  6265
# row:  6266
# row:  6267
# row:  6268
# row:  6269
# row:  6270
# Invalid Response
# row:  6271
# row:  6272
# row:  6273
# row:  6274
# row:  6275
# row:  6276
# row:  6277
# row:  6278
# row:  6279
# row:  6280
# row:  6281
# row:  6282
# row:  6283
# row:  6284
# row:  6285
# row:  6286
# row:  6287
# Invalid Response
# row:  6288
# row:  6289
# row:  6290
# row:  6291
# row:  6292
# row:  6293
# row:  6294
# row:  6295
# row:  6296
# row:  6297
# row:  6298
# row:  6299
# Time taken for 100 rows: 502.0681641101837
# row:  6300
# row:  6301
# row:  6302
# row:  6303
# row:  6304
# Invalid URL/ Timeout
# row:  6305
# row:  6306
# row:  6307
# row:  6308
# row:  6309
# row:  6310
# row:  6311
# row:  6312
# row:  6313
# Invalid URL/ Timeout
# row:  6314
# row:  6315
# row:  6316
# row:  6317
# row:  6318
# row:  6319
# row:  6320
# row:  6321
# row:  6322
# row:  6323
# row:  6324
# Invalid URL/ Timeout
# row:  6325
# Invalid Response
# row:  6326
# row:  6327
# row:  6328
# row:  6329
# Invalid Response
# row:  6330
# row:  6331
# row:  6332
# row:  6333
# Invalid URL/ Timeout
# row:  6334
# Invalid URL/ Timeout
# row:  6335
# row:  6336
# row:  6337
# row:  6338
# row:  6339
# row:  6340
# row:  6341
# row:  6342
# row:  6343
# row:  6344
# row:  6345
# row:  6346
# row:  6347
# row:  6348
# row:  6349
# row:  6350
# row:  6351
# row:  6352
# row:  6353
# row:  6354
# row:  6355
# row:  6356
# row:  6357
# Invalid URL/ Timeout
# row:  6358
# row:  6359
# row:  6360
# row:  6361
# Invalid URL/ Timeout
# row:  6362
# Invalid Response
# row:  6363
# row:  6364
# row:  6365
# row:  6366
# row:  6367
# row:  6368
# row:  6369
# row:  6370
# Invalid Response
# row:  6371
# row:  6372
# row:  6373
# row:  6374
# row:  6375
# row:  6376
# row:  6377
# row:  6378
# row:  6379
# ERROR:urllib3.connection:Certificate did not match expected hostname: piaggio.com. Certificate: {'subject': ((('countryName', 'IT'),), (('stateOrProvinceName', 'Pisa'),), (('localityName', 'Pontedera'),), (('organizationName', 'Piaggio & C. S.p.A.'),), (('organizationalUnitName', 'IT'),), (('commonName', '*.piaggiogroup.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'DigiCert Inc'),), (('organizationalUnitName', 'www.digicert.com'),), (('commonName', 'Thawte RSA CA 2018'),)), 'version': 3, 'serialNumber': '05F938DA1762C9944FFBB834C9553EB0', 'notBefore': 'Feb 11 00:00:00 2019 GMT', 'notAfter': 'Feb 11 12:00:00 2020 GMT', 'subjectAltName': (('DNS', '*.piaggiogroup.com'), ('DNS', 'piaggiogroup.com')), 'OCSP': ('http://status.thawte.com',), 'caIssuers': ('http://cacerts.thawte.com/ThawteRSACA2018.crt',), 'crlDistributionPoints': ('http://cdp.thawte.com/ThawteRSACA2018.crl',)}
# Invalid URL/ Timeout
# row:  6380
# row:  6381
# row:  6382
# row:  6383
# row:  6384
# row:  6385
# row:  6386
# row:  6387
# row:  6388
# row:  6389
# row:  6390
# row:  6391
# row:  6392
# row:  6393
# row:  6394
# row:  6395
# row:  6396
# row:  6397
# Invalid URL/ Timeout
# row:  6398
# row:  6399
# Time taken for 100 rows: 554.421350479126
# row:  6400
# row:  6401
# row:  6402
# row:  6403
# row:  6404
# row:  6405
# row:  6406
# row:  6407
# row:  6408
# row:  6409
# row:  6410
# row:  6411
# row:  6412
# Invalid Response
# row:  6413
# Invalid Response
# row:  6414
# row:  6415
# Invalid Response
# row:  6416
# row:  6417
# row:  6418
# row:  6419
# row:  6420
# row:  6421
# row:  6422
# row:  6423
# row:  6424
# Invalid Response
# row:  6425
# Invalid Response
# row:  6426
# Invalid URL/ Timeout
# row:  6427
# Invalid URL/ Timeout
# row:  6428
# Invalid URL/ Timeout
# row:  6429
# Invalid URL/ Timeout
# row:  6430
# row:  6431
# row:  6432
# row:  6433
# row:  6434
# row:  6435
# row:  6436
# Invalid Response
# row:  6437
# Invalid URL/ Timeout
# row:  6438
# row:  6439
# row:  6440
# Invalid URL/ Timeout
# row:  6441
# row:  6442
# Invalid URL/ Timeout
# row:  6443
# row:  6444
# row:  6445
# row:  6446
# Invalid URL/ Timeout
# row:  6447
# row:  6448
# row:  6449
# row:  6450
# row:  6451
# row:  6452
# row:  6453
# Invalid URL/ Timeout
# row:  6454
# Invalid URL/ Timeout
# row:  6455
# row:  6456
# row:  6457
# row:  6458
# row:  6459
# row:  6460
# row:  6461
# Invalid URL/ Timeout
# row:  6462
# row:  6463
# row:  6464
# row:  6465
# Invalid URL/ Timeout
# row:  6466
# row:  6467
# row:  6468
# Invalid URL/ Timeout
# row:  6469
# Invalid URL/ Timeout
# row:  6470
# row:  6471
# row:  6472
# row:  6473
# row:  6474
# row:  6475
# row:  6476
# row:  6477
# row:  6478
# row:  6479
# row:  6480
# Invalid URL/ Timeout
# row:  6481
# row:  6482
# row:  6483
# Invalid Response
# row:  6484
# row:  6485
# Invalid URL/ Timeout
# row:  6486
# row:  6487
# row:  6488
# row:  6489
# row:  6490
# row:  6491
# row:  6492
# Invalid URL/ Timeout
# row:  6493
# row:  6494
# row:  6495
# row:  6496
# row:  6497
# row:  6498
# row:  6499
# Time taken for 100 rows: 607.3663041591644
# row:  6500
# row:  6501
# row:  6502
# Invalid URL/ Timeout
# row:  6503
# row:  6504
# row:  6505
# row:  6506
# Invalid URL/ Timeout
# row:  6507
# row:  6508
# Invalid URL/ Timeout
# row:  6509
# row:  6510
# row:  6511
# row:  6512
# row:  6513
# row:  6514
# row:  6515
# row:  6516
# row:  6517
# row:  6518
# row:  6519
# row:  6520
# row:  6521
# row:  6522
# row:  6523
# row:  6524
# row:  6525
# row:  6526
# row:  6527
# row:  6528
# Invalid Response
# row:  6529
# row:  6530
# row:  6531
# row:  6532
# Invalid Response
# row:  6533
# row:  6534
# row:  6535
# Invalid Response
# row:  6536
# Invalid Response
# row:  6537
# row:  6538
# Invalid Response
# row:  6539
# row:  6540
# row:  6541
# row:  6542
# row:  6543
# row:  6544
# row:  6545
# row:  6546
# row:  6547
# row:  6548
# row:  6549
# row:  6550
# row:  6551
# Invalid Response
# row:  6552
# Invalid Response
# row:  6553
# Invalid URL/ Timeout
# row:  6554
# Invalid URL/ Timeout
# row:  6555
# row:  6556
# row:  6557
# row:  6558
# row:  6559
# row:  6560
# row:  6561
# row:  6562
# row:  6563
# row:  6564
# row:  6565
# row:  6566
# row:  6567
# row:  6568
# row:  6569
# row:  6570
# row:  6571
# row:  6572
# row:  6573
# row:  6574
# row:  6575
# row:  6576
# row:  6577
# Invalid URL/ Timeout
# row:  6578
# row:  6579
# Invalid Response
# row:  6580
# row:  6581
# row:  6582
# row:  6583
# Invalid Response
# row:  6584
# row:  6585
# row:  6586
# row:  6587
# row:  6588
# Invalid Response
# row:  6589
# Invalid Response
# row:  6590
# row:  6591
# row:  6592
# row:  6593
# row:  6594
# row:  6595
# Invalid Response
# row:  6596
# row:  6597
# Invalid URL/ Timeout
# row:  6598
# row:  6599
# Time taken for 100 rows: 573.249835729599
# row:  6600
# row:  6601
# row:  6602
# row:  6603
# row:  6604
# row:  6605
# row:  6606
# row:  6607
# row:  6608
# Invalid Response
# row:  6609
# row:  6610
# row:  6611
# Invalid Response
# row:  6612
# row:  6613
# row:  6614
# row:  6615
# row:  6616
# row:  6617
# Invalid Response
# row:  6618
# row:  6619
# Invalid Response
# row:  6620
# row:  6621
# row:  6622
# row:  6623
# row:  6624
# row:  6625
# row:  6626
# row:  6627
# Invalid URL/ Timeout
# row:  6628
# Invalid URL/ Timeout
# row:  6629
# row:  6630
# Invalid URL/ Timeout
# row:  6631
# row:  6632
# row:  6633
# row:  6634
# row:  6635
# row:  6636
# row:  6637
# row:  6638
# row:  6639
# row:  6640
# row:  6641
# Invalid URL/ Timeout
# row:  6642
# row:  6643
# row:  6644
# row:  6645
# row:  6646
# row:  6647
# row:  6648
# row:  6649
# Invalid URL/ Timeout
# row:  6650
# row:  6651
# Invalid URL/ Timeout
# row:  6652
# row:  6653
# row:  6654
# Invalid Response
# row:  6655
# row:  6656
# Invalid URL/ Timeout
# row:  6657
# row:  6658
# row:  6659
# row:  6660
# row:  6661
# row:  6662
# row:  6663
# Invalid Response
# row:  6664
# row:  6665
# Invalid Response
# row:  6666
# Invalid Response
# row:  6667
# row:  6668
# row:  6669
# Invalid Response
# row:  6670
# row:  6671
# row:  6672
# row:  6673
# Invalid Response
# row:  6674
# row:  6675
# Invalid URL/ Timeout
# row:  6676
# row:  6677
# row:  6678
# row:  6679
# Invalid URL/ Timeout
# row:  6680
# row:  6681
# row:  6682
# row:  6683
# row:  6684
# row:  6685
# row:  6686
# Invalid Response
# row:  6687
# row:  6688
# row:  6689
# Invalid URL/ Timeout
# row:  6690
# row:  6691
# row:  6692
# row:  6693
# Invalid URL/ Timeout
# row:  6694
# row:  6695
# row:  6696
# row:  6697
# row:  6698
# row:  6699
# Time taken for 100 rows: 451.8883726596832
# row:  6700
# row:  6701
# row:  6702
# row:  6703
# row:  6704
# row:  6705
# row:  6706
# Invalid Response
# row:  6707
# row:  6708
# row:  6709
# row:  6710
# row:  6711
# row:  6712
# row:  6713
# row:  6714
# row:  6715
# row:  6716
# row:  6717
# row:  6718
# row:  6719
# row:  6720
# row:  6721
# row:  6722
# Invalid URL/ Timeout
# row:  6723
# Invalid Response
# row:  6724
# Invalid URL/ Timeout
# row:  6725
# row:  6726
# row:  6727
# row:  6728
# row:  6729
# row:  6730
# row:  6731
# row:  6732
# row:  6733
# row:  6734
# row:  6735
# Invalid URL/ Timeout
# row:  6736
# row:  6737
# row:  6738
# Invalid URL/ Timeout
# row:  6739
# Invalid Response
# row:  6740
# row:  6741
# row:  6742
# row:  6743
# row:  6744
# Invalid URL/ Timeout
# row:  6745
# row:  6746
# row:  6747
# row:  6748
# row:  6749
# Invalid URL/ Timeout
# row:  6750
# row:  6751
# row:  6752
# row:  6753
# row:  6754
# Invalid URL/ Timeout
# row:  6755
# row:  6756
# row:  6757
# row:  6758
# row:  6759
# row:  6760
# Invalid Response
# row:  6761
# row:  6762
# row:  6763
# row:  6764
# Invalid URL/ Timeout
# row:  6765
# row:  6766
# Invalid Response
# row:  6767
# row:  6768
# row:  6769
# row:  6770
# row:  6771
# row:  6772
# row:  6773
# Invalid URL/ Timeout
# row:  6774
# row:  6775
# row:  6776
# Invalid URL/ Timeout
# row:  6777
# Invalid URL/ Timeout
# row:  6778
# row:  6779
# row:  6780
# row:  6781
# row:  6782
# row:  6783
# Invalid Response
# row:  6784
# row:  6785
# row:  6786
# row:  6787
# row:  6788
# row:  6789
# row:  6790
# row:  6791
# row:  6792
# Invalid URL/ Timeout
# row:  6793
# row:  6794
# row:  6795
# Invalid Response
# row:  6796
# row:  6797
# row:  6798
# row:  6799
# Time taken for 100 rows: 419.22881865501404
# row:  6800
# row:  6801
# row:  6802
# row:  6803
# row:  6804
# row:  6805
# row:  6806
# row:  6807
# row:  6808
# row:  6809
# Invalid URL/ Timeout
# row:  6810
# row:  6811
# row:  6812
# Invalid URL/ Timeout
# row:  6813
# row:  6814
# row:  6815
# Invalid Response
# row:  6816
# Invalid URL/ Timeout
# row:  6817
# row:  6818
# row:  6819
# row:  6820
# Invalid URL/ Timeout
# row:  6821
# row:  6822
# row:  6823
# row:  6824
# Invalid Response
# row:  6825
# Invalid Response
# row:  6826
# row:  6827
# row:  6828
# row:  6829
# Invalid Response
# row:  6830
# row:  6831
# row:  6832
# row:  6833
# Invalid URL/ Timeout
# row:  6834
# row:  6835
# row:  6836
# row:  6837
# row:  6838
# Invalid URL/ Timeout
# row:  6839
# row:  6840
# Invalid URL/ Timeout
# row:  6841
# row:  6842
# row:  6843
# row:  6844
# row:  6845
# row:  6846
# Invalid Response
# row:  6847
# row:  6848
# row:  6849
# row:  6850
# row:  6851
# row:  6852
# row:  6853
# row:  6854
# Invalid URL/ Timeout
# row:  6855
# row:  6856
# row:  6857
# row:  6858
# row:  6859
# row:  6860
# Invalid URL/ Timeout
# row:  6861
# Invalid Response
# row:  6862
# Invalid Response
# row:  6863
# Invalid Response
# row:  6864
# Invalid Response
# row:  6865
# Invalid URL/ Timeout
# row:  6866
# row:  6867
# row:  6868
# row:  6869
# row:  6870
# Invalid URL/ Timeout
# row:  6871
# row:  6872
# row:  6873
# Invalid Response
# row:  6874
# row:  6875
# row:  6876
# row:  6877
# Invalid Response
# row:  6878
# row:  6879
# row:  6880
# row:  6881
# Invalid Response
# row:  6882
# row:  6883
# Invalid URL/ Timeout
# row:  6884
# row:  6885
# row:  6886
# row:  6887
# row:  6888
# row:  6889
# row:  6890
# row:  6891
# row:  6892
# row:  6893
# row:  6894
# Invalid Response
# row:  6895
# Invalid URL/ Timeout
# row:  6896
# row:  6897
# Invalid URL/ Timeout
# row:  6898
# row:  6899
# Time taken for 100 rows: 410.929888010025
# row:  6900
# row:  6901
# row:  6902
# row:  6903
# row:  6904
# row:  6905
# Invalid Response
# row:  6906
# row:  6907
# row:  6908
# row:  6909
# row:  6910
# row:  6911
# Invalid Response
# row:  6912
# row:  6913
# row:  6914
# row:  6915
# row:  6916
# row:  6917
# row:  6918
# row:  6919
# Invalid URL/ Timeout
# row:  6920
# row:  6921
# row:  6922
# row:  6923
# row:  6924
# row:  6925
# row:  6926
# row:  6927
# row:  6928
# row:  6929
# row:  6930
# Invalid URL/ Timeout
# row:  6931
# row:  6932
# Invalid Response
# row:  6933
# Invalid Response
# row:  6934
# row:  6935
# Invalid URL/ Timeout
# row:  6936
# row:  6937
# row:  6938
# row:  6939
# row:  6940
# row:  6941
# row:  6942
# row:  6943
# row:  6944
# row:  6945
# row:  6946
# row:  6947
# row:  6948
# row:  6949
# row:  6950
# row:  6951
# row:  6952
# row:  6953
# Invalid URL/ Timeout
# row:  6954
# row:  6955
# row:  6956
# row:  6957
# row:  6958
# row:  6959
# Invalid Response
# row:  6960
# row:  6961
# row:  6962
# row:  6963
# row:  6964
# row:  6965
# row:  6966
# row:  6967
# Invalid URL/ Timeout
# row:  6968
# row:  6969
# row:  6970
# row:  6971
# row:  6972
# row:  6973
# row:  6974
# row:  6975
# row:  6976
# row:  6977
# row:  6978
# row:  6979
# row:  6980
# row:  6981
# row:  6982
# row:  6983
# row:  6984
# row:  6985
# row:  6986
# row:  6987
# row:  6988
# Invalid Response
# row:  6989
# Invalid URL/ Timeout
# row:  6990
# row:  6991
# Invalid URL/ Timeout
# row:  6992
# row:  6993
# row:  6994
# row:  6995
# row:  6996
# row:  6997
# row:  6998
# row:  6999
# Time taken for 100 rows: 426.19610357284546
# row:  7000
# row:  7001
# row:  7002
# row:  7003
# ERROR:urllib3.connection:Certificate did not match expected hostname: voyage-prive.it. Certificate: {'subject': ((('serialNumber', '479 345 043 00034'),), (('jurisdictionCountryName', 'FR'),), (('jurisdictionStateOrProvinceName', 'PACA'),), (('jurisdictionLocalityName', 'Aix en Provence'),), (('businessCategory', 'Private Organization'),), (('countryName', 'FR'),), (('postalCode', '13100'),), (('stateOrProvinceName', 'PACA'),), (('localityName', 'Aix en Provence'),), (('streetAddress', '684 Avenue du Club Hippique'),), (('organizationName', 'VOYAGE PRIVE (VPG)'),), (('organizationalUnitName', 'COMODO EV Multi-Domain SSL'),), (('commonName', 'www.voyage-prive.com'),)), 'issuer': ((('countryName', 'GB'),), (('stateOrProvinceName', 'Greater Manchester'),), (('localityName', 'Salford'),), (('organizationName', 'COMODO CA Limited'),), (('commonName', 'COMODO RSA Extended Validation Secure Server CA'),)), 'version': 3, 'serialNumber': '627C0DE0401FEF7A51A3986EA5230260', 'notBefore': 'Jun  6 00:00:00 2018 GMT', 'notAfter': 'Sep  2 23:59:59 2020 GMT', 'subjectAltName': (('DNS', 'www.voyage-prive.com'), ('DNS', 'front-admin.voyage-prive.be'), ('DNS', 'front-admin.voyage-prive.ch'), ('DNS', 'front-admin.voyage-prive.co.uk'), ('DNS', 'front-admin.voyage-prive.com'), ('DNS', 'front-admin.voyage-prive.de'), ('DNS', 'front-admin.voyage-prive.es'), ('DNS', 'front-admin.voyage-prive.fr'), ('DNS', 'front-admin.voyage-prive.it'), ('DNS', 'front-admin.voyage-prive.nl'), ('DNS', 'front-admin.voyage-prive.pl'), ('DNS', 'secure.voyage-prive.be'), ('DNS', 'secure.voyage-prive.ch'), ('DNS', 'secure.voyage-prive.co.uk'), ('DNS', 'secure.voyage-prive.com'), ('DNS', 'secure.voyage-prive.de'), ('DNS', 'secure.voyage-prive.es'), ('DNS', 'secure.voyage-prive.fr'), ('DNS', 'secure.voyage-prive.it'), ('DNS', 'secure.voyage-prive.nl'), ('DNS', 'secure.voyage-prive.pl'), ('DNS', 'voyageprive.com'), ('DNS', 'www.voyage-prive.be'), ('DNS', 'www.voyage-prive.ch'), ('DNS', 'www.voyage-prive.co.uk'), ('DNS', 'www.voyage-prive.de'), ('DNS', 'www.voyage-prive.es'), ('DNS', 'www.voyage-prive.fr'), ('DNS', 'www.voyage-prive.it'), ('DNS', 'www.voyage-prive.nl'), ('DNS', 'www.voyage-prive.pl'), ('DNS', 'www.voyageprive.com')), 'OCSP': ('http://ocsp.comodoca.com',), 'caIssuers': ('http://crt.comodoca.com/COMODORSAExtendedValidationSecureServerCA.crt',), 'crlDistributionPoints': ('http://crl.comodoca.com/COMODORSAExtendedValidationSecureServerCA.crl',)}
# Invalid URL/ Timeout
# row:  7004
# row:  7005
# row:  7006
# row:  7007
# Invalid Response
# row:  7008
# row:  7009
# row:  7010
# row:  7011
# row:  7012
# row:  7013
# row:  7014
# Invalid Response
# row:  7015
# row:  7016
# row:  7017
# row:  7018
# row:  7019
# row:  7020
# row:  7021
# row:  7022
# Invalid URL/ Timeout
# row:  7023
# row:  7024
# row:  7025
# row:  7026
# Invalid Response
# row:  7027
# row:  7028
# row:  7029
# row:  7030
# row:  7031
# row:  7032
# row:  7033
# row:  7034
# row:  7035
# row:  7036
# row:  7037
# row:  7038
# row:  7039
# row:  7040
# Invalid URL/ Timeout
# row:  7041
# Invalid Response
# row:  7042
# Invalid Response
# row:  7043
# row:  7044
# row:  7045
# row:  7046
# row:  7047
# row:  7048
# row:  7049
# row:  7050
# row:  7051
# row:  7052
# row:  7053
# row:  7054
# row:  7055
# row:  7056
# row:  7057
# row:  7058
# row:  7059
# row:  7060
# row:  7061
# row:  7062
# row:  7063
# row:  7064
# row:  7065
# row:  7066
# row:  7067
# row:  7068
# row:  7069
# row:  7070
# row:  7071
# row:  7072
# row:  7073
# Invalid URL/ Timeout
# row:  7074
# Invalid URL/ Timeout
# row:  7075
# Invalid URL/ Timeout
# row:  7076
# row:  7077
# row:  7078
# row:  7079
# row:  7080
# row:  7081
# row:  7082
# row:  7083
# row:  7084
# Invalid Response
# row:  7085
# row:  7086
# row:  7087
# row:  7088
# Invalid URL/ Timeout
# row:  7089
# row:  7090
# row:  7091
# Invalid Response
# row:  7092
# row:  7093
# row:  7094
# row:  7095
# row:  7096
# row:  7097
# row:  7098
# row:  7099
# Time taken for 100 rows: 384.75163173675537
# row:  7100
# row:  7101
# row:  7102
# Invalid Response
# row:  7103
# row:  7104
# row:  7105
# row:  7106
# row:  7107
# row:  7108
# row:  7109
# Invalid URL/ Timeout
# row:  7110
# row:  7111
# Invalid Response
# row:  7112
# Invalid Response
# row:  7113
# row:  7114
# Invalid Response
# row:  7115
# row:  7116
# row:  7117
# Invalid URL/ Timeout
# row:  7118
# Invalid URL/ Timeout
# row:  7119
# row:  7120
# row:  7121
# row:  7122
# row:  7123
# row:  7124
# Invalid URL/ Timeout
# row:  7125
# row:  7126
# row:  7127
# row:  7128
# row:  7129
# row:  7130
# row:  7131
# row:  7132
# row:  7133
# Invalid Response
# row:  7134
# row:  7135
# row:  7136
# row:  7137
# row:  7138
# row:  7139
# row:  7140
# row:  7141
# row:  7142
# row:  7143
# row:  7144
# row:  7145
# row:  7146
# row:  7147
# row:  7148
# row:  7149
# row:  7150
# row:  7151
# row:  7152
# row:  7153
# Invalid Response
# row:  7154
# row:  7155
# row:  7156
# row:  7157
# row:  7158
# row:  7159
# row:  7160
# row:  7161
# Invalid Response
# row:  7162
# row:  7163
# row:  7164
# row:  7165
# row:  7166
# Invalid URL/ Timeout
# row:  7167
# Invalid Response
# row:  7168
# row:  7169
# row:  7170
# row:  7171
# row:  7172
# row:  7173
# row:  7174
# row:  7175
# row:  7176
# row:  7177
# Invalid URL/ Timeout
# row:  7178
# row:  7179
# Invalid URL/ Timeout
# row:  7180
# row:  7181
# row:  7182
# row:  7183
# Invalid URL/ Timeout
# row:  7184
# row:  7185
# row:  7186
# row:  7187
# row:  7188
# row:  7189
# row:  7190
# row:  7191
# Invalid Response
# row:  7192
# row:  7193
# row:  7194
# row:  7195
# row:  7196
# row:  7197
# row:  7198
# row:  7199
# Time taken for 100 rows: 450.0341658592224
# row:  7200
# row:  7201
# Invalid Response
# row:  7202
# row:  7203
# row:  7204
# row:  7205
# row:  7206
# row:  7207
# row:  7208
# Invalid Response
# row:  7209
# row:  7210
# row:  7211
# row:  7212
# row:  7213
# row:  7214
# row:  7215
# row:  7216
# row:  7217
# row:  7218
# row:  7219
# row:  7220
# row:  7221
# row:  7222
# row:  7223
# row:  7224
# row:  7225
# row:  7226
# row:  7227
# row:  7228
# row:  7229
# Invalid Response
# row:  7230
# row:  7231
# Invalid URL/ Timeout
# row:  7232
# row:  7233
# row:  7234
# row:  7235
# row:  7236
# row:  7237
# row:  7238
# row:  7239
# Invalid URL/ Timeout
# row:  7240
# row:  7241
# row:  7242
# row:  7243
# row:  7244
# row:  7245
# row:  7246
# Invalid Response
# row:  7247
# row:  7248
# row:  7249
# Invalid URL/ Timeout
# row:  7250
# row:  7251
# row:  7252
# ERROR:urllib3.connection:Certificate did not match expected hostname: hyundaiusa.com. Certificate: {'subject': ((('businessCategory', 'Private Organization'),), (('jurisdictionCountryName', 'US'),), (('jurisdictionStateOrProvinceName', 'California'),), (('serialNumber', 'C1274114'),), (('countryName', 'US'),), (('stateOrProvinceName', 'California'),), (('localityName', 'Fountain Valley'),), (('organizationName', 'Hyundai Motor America'),), (('organizationalUnitName', 'IT'),), (('commonName', 'www.hyundaiusa.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'DigiCert Inc'),), (('organizationalUnitName', 'www.digicert.com'),), (('commonName', 'DigiCert SHA2 Extended Validation Server CA'),)), 'version': 3, 'serialNumber': '0B6342BBED6A2AB59AF2B30634EED4FF', 'notBefore': 'Jun 28 00:00:00 2018 GMT', 'notAfter': 'Jul  5 12:00:00 2019 GMT', 'subjectAltName': (('DNS', 'www.hyundaiusa.com'),), 'OCSP': ('http://ocsp.digicert.com',), 'caIssuers': ('http://cacerts.digicert.com/DigiCertSHA2ExtendedValidationServerCA.crt',), 'crlDistributionPoints': ('http://crl3.digicert.com/sha2-ev-server-g2.crl', 'http://crl4.digicert.com/sha2-ev-server-g2.crl')}
# Invalid URL/ Timeout
# row:  7253
# row:  7254
# Invalid Response
# row:  7255
# Invalid URL/ Timeout
# row:  7256
# row:  7257
# row:  7258
# row:  7259
# row:  7260
# row:  7261
# row:  7262
# row:  7263
# row:  7264
# row:  7265
# row:  7266
# Invalid URL/ Timeout
# row:  7267
# row:  7268
# Invalid URL/ Timeout
# row:  7269
# row:  7270
# row:  7271
# row:  7272
# row:  7273
# row:  7274
# row:  7275
# row:  7276
# row:  7277
# row:  7278
# row:  7279
# Invalid URL/ Timeout
# row:  7280
# row:  7281
# row:  7282
# row:  7283
# row:  7284
# row:  7285
# row:  7286
# row:  7287
# row:  7288
# row:  7289
# row:  7290
# row:  7291
# row:  7292
# row:  7293
# row:  7294
# row:  7295
# row:  7296
# row:  7297
# row:  7298
# row:  7299
# Time taken for 100 rows: 451.48802638053894
# row:  7300
# row:  7301
# row:  7302
# row:  7303
# row:  7304
# row:  7305
# Invalid Response
# row:  7306
# row:  7307
# Invalid URL/ Timeout
# row:  7308
# row:  7309
# row:  7310
# row:  7311
# row:  7312

# %%
# data.to_csv('data_with_lang_labels.csv', index=False)
data = pd.read_csv('data_with_lang_labels.csv')
data.iloc[7300:]
# Out:
#                                           business_name  \
# 7300                                      Prada Fashion
# 7301                            Roland Schuhe - Germany
# 7302                           Samsung - United Kingdom
# 7303                                      SBB - Germany
# 7304                                 Seventh Generation
# 7305                              Soleil Sucr? - France
# 7306                Sueddeutsche Zeitung GmbH - Germany
# 7307  TBG Thermenzentrum Geinberg BetriebsgmbH - Aus...
# 7308                     Tons of Tiles - United Kingdom
# 7309                                ufxmarkets - France
# 7310                               Wegmans Food Markets
# 7311                              Wesco Family - France
# 7312                                      Zalando Spain
#
#             google1_correct_website   business_category  \
# 7300              http://prada.com/              Retail
# 7301       http://roland-schuhe.de/              Retail
# 7302         http://samsung.com/uk/              Retail
# 7303                 http://sbb.ch/              Travel
# 7304  http://seventhgeneration.com/                 CPG
# 7305        http://soleilsucre.com/              Retail
# 7306        http://sueddeutsche.de/               Other
# 7307  http://therme-geinberg.at/de/              Travel
# 7308      http://tonsoftiles.co.uk/              Retail
# 7309         http://ufxmarkets.com/  Financial Services
# 7310            http://wegmans.com/                 CPG
# 7311        http://wesco-family.fr/              Retail
# 7312             http://zalando.es/              Retail
#
#                                            site-content site-language
# 7300  PRADA - OFFICIAL WEBSITE _.Resort 2020 Womensw...            en
# 7301  ROLAND Onlineshop – Schuhe, Taschen und Access...            de
# 7302  Samsung UK | Mobile | Home Electronics | Home ...            en
# 7303  Alles für Ihre Mobilität | SBB Navigieren auf ...            de
# 7304  Homepage | Seventh Generation Skip to main con...            en
# 7305                                                NaN           NaN
# 7306  Nachrichten aus Politik, Kultur, Wirtschaft un...            de
# 7307                                                NaN           NaN
# 7308  Bathroom & Kitchen Tiles | Wall & Floor Decor ...            en
# 7309  UFX.com - Where Trading Makes Sense. #1 CFD On...            en
# 7310  Home - Wegmans Home.Departments.Meals & Recipe...            en
# 7311  Wesco : mobilier enfant, puériculture, jeux et...            fr
# 7312  Zapatos y ropa online | La mejor selecciÃ³n en...            es

# %%
data_sub = data.dropna()

# %%
data_sub.shape
# Out:
# (5681, 5)

# %% [markdown]
# ### Language distribution

# %%
data_sub['site-language'].value_counts()
# Out:
# en       4144
# de        842
# es        193
# fr        172
# it        116
# pt         67
# pl         31
# tr         16
# ro         10
# nl         10
# hu          9
# ca          9
# ja          8
# tl          8
# fi          5
# da          5
# ru          4
# ko          4
# cy          3
# mr          3
# cs          3
# id          3
# no          2
# hr          2
# hi          2
# zh-cn       2
# sk          2
# lt          1
# vi          1
# et          1
# th          1
# sv          1
# af          1
# Name: site-language, dtype: int64

# %% [markdown]
# ## Modeling on English Data

# %%
website_stopwords = ["skip", "about", "menu", "contact", "cookies", "login"]

# %%
data_en = data_sub[data_sub['site-language']=='en']

# %%
data_en["site-content"] = data_en["site-content"].apply(lambda x: re.sub('[^a-zA-Z ]', " ", x))
# Out:
# /home/ubuntu/miniconda/envs/cv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# data_en.to_csv('data_english_sites.csv',index=False)

data_en = pd.read_csv('data_english_sites.csv')

# %%
data_en.head()
# Out:
#       business_name               google1_correct_website   business_category  \
# 0         Central 1                  http://central1.com/  Financial Services
# 1  ad tech | iMedia                   http://ad-tech.com/               Other
# 2           Adotmob                   http://adotmob.com/               Other
# 3   BBC Advertising  http://advertising.bbcworldwide.com/               Other
# 4              airG                      http://airg.com/               Other
#
#                                         site-content site-language
# 0  Search for  Join our team  we re growing  VIEW...            en
# 1  Skip to main content ad tech Australia Sydney ...            en
# 2  MENU MENU Home Know how Data Technologies Solu...            en
# 3  Toggle navigation SPECS SPECS CONTACT SPECS CO...            en
# 4  Have we met before  WELCOME TO AIRG Login Sign...            en

# %%
# nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('english')
stop_words.extend(website_stopwords)

# %%
tfidf = TfidfVectorizer(stop_words=stop_words)
tfidf_vector = tfidf.fit_transform(data_en["site-content"])

# %%
with open('tfidf_en.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

# %%
with open('tfidf_en.pkl', 'rb') as f:
    tfidf = pickle.load(f)
# Out:
# /home/ubuntu/miniconda3/envs/url_mapper/lib/python3.6/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.20.1 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/ubuntu/miniconda3/envs/url_mapper/lib/python3.6/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.20.1 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
# tfidf_vector = tfidf.transform(data_en["site-content"])

# %%
print(sorted(tfidf.vocabulary_.keys()))
# Out:
# ['aa', 'aaa', 'aaah', 'aaaron', 'aabc', 'aabou', 'aaboulevarden', 'aac', 'aacc', 'aacer', 'aachen', 'aacn', 'aacsb', 'aacsf', 'aad', 'aadvantage', 'aadvws', 'aae', 'aaf', 'aafco', 'aafp', 'aag', 'aah', 'aai', 'aaic', 'aaii', 'aaland', 'aalborg', 'aam', 'aamani', 'aami', 'aans', 'aao', 'aap', 'aapg', 'aapka', 'aapl', 'aarf', 'aarg', 'aarhus', 'aaron', 'aarons', 'aarp', 'aarti', 'aas', 'aasp', 'aavsb', 'ab', 'aba', 'abaco', 'abacus', 'abadia', 'abagail', 'abama', 'abandon', 'abandonded', 'abandoned', 'abandonment', 'abap', 'abapps', 'abarth', 'abate', 'abategioielli', 'abayas', 'abb', 'abbas', 'abbauprodukte', 'abbey', 'abbot', 'abbotsford', 'abbott', 'abbottstore', 'abboud', 'abbrechen', 'abbreviated', 'abbreviation', 'abbvie', 'abby', 'abc', 'abcs', 'abdeck', 'abdeckt', 'abdominal', 'abducted', 'abduction', 'abductions', 'abdul', 'abdulai', 'abdulrahim', 'abe', 'abel', 'abele', 'abell', 'abendroth', 'abends', 'abeno', 'abenoharukas', 'abenosuji', 'abenteuer', 'abenteuerlustige', 'abeo', 'aber', 'abercorn', 'abercrombie', 'aberdeen', 'abermals', 'abestronaut', 'abg', 'abgang', 'abgeben', 'abgebrannt', 'abgedeckt', 'abgehoben', 'abgemeldet', 'abgestimmt', 'abgewiesen', 'abh', 'abhishek', 'abide', 'abides', 'abigail', 'abilene', 'abilirsiniz', 'abilit', 'abilities', 'ability', 'abilitylab', 'abinbev', 'abingdon', 'abington', 'abiqui', 'abiquiu', 'abiseo', 'abitibi', 'abl', 'ablation', 'able', 'ablehnen', 'ableton', 'abload', 'abloh', 'ablqacdsxa', 'abm', 'abmat', 'abmats', 'abn', 'abnjk', 'abnormal', 'abnormality', 'abns', 'abo', 'aboard', 'abobotulinumtoxina', 'abode', 'abominable', 'abonnement', 'abord', 'aboriginal', 'abortion', 'abortus', 'abound', 'abounding', 'abounds', 'aboutads', 'aboutcookies', 'aboutme', 'aboutmedefaultcontent', 'aboutus', 'abp', 'abq', 'abr', 'abraham', 'abrahams', 'abrakam', 'abram', 'abrams', 'abrasion', 'abrasive', 'abrasives', 'abreast', 'abric', 'abroad', 'abrupt', 'abruptly', 'abruzzo', 'abry', 'abs', 'absage', 'abschicken', 'abschluss', 'absence', 'absent', 'absinthe', 'absolu', 'absolue', 'absolum', 'absolut', 'absolute', 'absolutely', 'absolutly', 'absolvent', 'absolventen', 'absolventin', 'absolventinnen', 'absolvieren', 'absolviert', 'absolvierte', 'absolvierung', 'absorb', 'absorbed', 'absorbent', 'absorbents', 'absorber', 'absorbers', 'absorbing', 'absorcer', 'absorption', 'absperrgitter', 'abst', 'abstainers', 'abstinence', 'abstract', 'abstractions', 'abstracts', 'abt', 'abta', 'abteilung', 'abteilungsleiterin', 'abtot', 'abu', 'abundance', 'abundant', 'abundantly', 'abus', 'abuse', 'abused', 'abuser', 'abusers', 'abuses', 'abusing', 'abusive', 'abuzz', 'abwechslungsreiche', 'abwr', 'abzielen', 'abzorba', 'ac', 'aca', 'acacia', 'acad', 'acade', 'academia', 'academic', 'academically', 'academicians', 'academics', 'academicus', 'academies', 'academixdirect', 'academy', 'acadia', 'acai', 'acana', 'acantha', 'acap', 'acappella', 'acapulco', 'acar', 'acas', 'acaster', 'acb', 'acbbda', 'acbsp', 'acc', 'acca', 'accademia', 'accanews', 'accce', 'acccommodation', 'acce', 'accedere', 'accel', 'accelerant', 'accelerate', 'accelerated', 'accelerates', 'accelerati', 'accelerating', 'acceleration', 'accelerator', 'accelerators', 'acceleron', 'accent', 'accented', 'accents', 'accentuate', 'accenture', 'accept', 'acceptable', 'acceptance', 'acceptances', 'accepted', 'acceptez', 'accepting', 'accepts', 'acceso', 'accesories', 'accesory', 'access', 'accessed', 'accesses', 'accessibility', 'accessibilityheadertext', 'accessibilty', 'accessible', 'accessing', 'accesskey', 'accesskeys', 'accessmonitor', 'accessnet', 'accesso', 'accessoires', 'accessor', 'accessorie', 'accessories', 'accessorise', 'accessorize', 'accessorizing', 'accessory', 'accesspointe', 'accesstoken', 'accetto', 'accident', 'accidental', 'accidentally', 'accidentes', 'accidents', 'accilium', 'accio', 'accjc', 'acclaim', 'acclaimed', 'acclavio', 'acclimatation', 'accolade', 'accolades', 'accommodate', 'accommodated', 'accommodates', 'accom ...

# %%
X_tfidf = tfidf_vector.toarray()

# %%
X_tfidf.shape
# Out:
# (4144, 75271)

# %%
le = LabelEncoder()
y_tfidf = le.fit_transform(data_en['business_category'])

# %%
data_en['business_category'].value_counts()
# Out:
# Other                 2206
# Retail                 830
# Financial Services     368
# CPG                    299
# Travel                 292
# Auto                   149
# Name: business_category, dtype: int64

# %%
pd.Series(y_tfidf).value_counts()
# Out:
# 3    2206
# 4     830
# 2     368
# 1     299
# 5     292
# 0     149
# dtype: int64

# %%
data_en['business_category'].value_counts()/data_en.shape[0]
# Out:
# Other                 0.532336
# Retail                0.200290
# Financial Services    0.088803
# CPG                   0.072153
# Travel                0.070463
# Auto                  0.035956
# Name: business_category, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_tfidf, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((2900, 75271), (1244, 75271))

# %% [markdown]
# ### Handling Imbalanced Class

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)

# %%
X_ros_train, y_ros_train = ros.fit_sample(X_train, y_train)

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(random_state=42)
lr.fit(X_ros_train, y_ros_train)
# Out:
# /home/ubuntu/miniconda3/envs/url_mapper/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ubuntu/miniconda3/envs/url_mapper/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=42, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr.score(X_train, y_train)
# Out:
# 0.93

# %%
lr.score(X_test, y_test)
# Out:
# 0.8014469453376206

# %%
with open('model_lr.pkl', 'wb') as f:
    pickle.dump(lr, f)

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb = MultinomialNB()

# %%
nb.fit(X_ros_train, y_ros_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
nb.score(X_train, y_train)
# Out:
# 0.8644827586206897

# %%
nb.score(X_test, y_test)
# Out:
# 0.7467845659163987

# %%
with open('model_naiveb.pkl', 'wb') as f:
    pickle.dump(nb, f)

# %% [markdown]
# ### Linear SVM

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='linear', random_state=42)

# %%
svc.fit(X_ros_train, y_ros_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=42,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc.score(X_test, y_test)
# Out:
# 0.772508038585209

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=30, max_depth=30, min_samples_leaf=10)

# %%
rf.fit(X_ros_train, y_ros_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=30, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=10, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=30,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf.score(X_train, y_train)
# Out:
# 0.8548275862068966

# %%
rf.score(X_test, y_test)
# Out:
# 0.7508038585209004

# %%
with open('model_rf.pkl', 'wb') as f:
    pickle.dump(rf, f)

# %% [markdown]
# ### VotingClassifier

# %%
from sklearn.ensemble import VotingClassifier

# %%
vc = VotingClassifier(estimators = [('lr',lr), ('nb',nb), ('rf',rf)])

# %%
vc.fit(X_ros_train, y_ros_train)
# Out:
# /home/ubuntu/miniconda3/envs/url_mapper/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/ubuntu/miniconda3/envs/url_mapper/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='warn',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=42, solver='warn',
#                                                  tol=0.0001, verbose=0,
#                                                  warm_start=False)),
#                              ('nb',
#                               MultinomialNB(alpha=1.0, class_prior=None,
#                                             fit_prior=True)),
#                              ('rf',
#                               RandomFores...
#                                                      class_weight=None,
#                                                      criterion='gini',
#                                                      max_depth=30,
#                                                      max_features='auto',
#                                                      max_leaf_nodes=None,
#                                                      min_impurity_decrease=0.0,
#                                                      min_impurity_split=None,
#                                                      min_samples_leaf=10,
#                                                      min_samples_split=2,
#                                                      min_weight_fraction_leaf=0.0,
#                                                      n_estimators=30,
#                                                      n_jobs=None,
#                                                      oob_score=False,
#                                                      random_state=None,
#                                                      verbose=0,
#                                                      warm_start=False))],
#                  flatten_transform=True, n_jobs=None, voting='hard',
#                  weights=None)

# %%
vc.score(X_train,y_train)
# Out:
# 0.9055172413793103

# %%
vc.score(X_test, y_test)
# Out:
# 0.7877813504823151

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, vc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.76      0.70        51
#            1       0.59      0.74      0.66        95
#            2       0.69      0.74      0.71        96
#            3       0.84      0.86      0.85       673
#            4       0.79      0.62      0.69       250
#            5       0.82      0.81      0.82        79
#
#     accuracy                           0.79      1244
#    macro avg       0.73      0.76      0.74      1244
# weighted avg       0.79      0.79      0.79      1244

# %%
with open('model_ensemble.pkl', 'wb') as f:
    pickle.dump(vc, f)

# %%
text = "Hello world. How do you do ? It's a pleasure to meet you ! We sell cars and bikes to our esteemed customers"

# %%
new_vector = tfidf.transform([text])

# %%
X_new = new_vector.toarray()

# %%
vc.predict(X_new)
# Out:
# array([0])

# %%
class_mapping = {0:"Auto", 1:"CPG", 2:"Financial Services", 3:"Other", 4:"Retail", 5:"Travel"}

# %% [markdown]
# ## Lemmatized columns
